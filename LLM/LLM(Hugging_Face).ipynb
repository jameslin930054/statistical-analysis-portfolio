# %% [markdown]
# <a href="https://colab.research.google.com/github/jameslin930054/statistical-analysis-portfolio/blob/main/LLM/LLM(Hugging_Face).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 本專案透過實際執行與分析大型語言模型（Large Language Model, LLM）相關程式碼，深入了解模型內部神經網路的運作原理與推論流程。
#
# 實作過程中，完成執行環境建置、套件安裝、程式除錯及模型執行，並針對程式架構與各模組功能進行分析，理解神經網路前向傳播、權重運算及資料流向等核心概念。
#
# 透過本專案，累積了大型語言模型實作、程式碼閱讀、問題排除及模型執行流程分析等實務經驗，並加深對 LLM 基本架構與運作機制的理解。

# %%
# !pip install -U transformers #安裝 HuggingFace Transformers 套件
import torch
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Collecting transformers
#   Downloading transformers-5.5.3-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.8.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Downloading transformers-5.5.3-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 22.4 MB/s eta 0:00:00
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.0
#     Uninstalling transformers-5.0.0:
#       Successfully uninstalled transformers-5.0.0
# Successfully installed transformers-5.5.3

# %% [markdown]
# 在載入預訓練模型之前，需先完成 Hugging Face Hub 的身分驗證，以取得模型下載與存取權限。專案使用 Hugging Face Access Token 作為 API 認證憑證，完成登入後即可透過程式自動下載所需模型與相關資源。
#
# 透過此步驟，熟悉 Hugging Face Hub 的模型管理機制、Access Token 驗證流程，以及模型下載與部署的基本操作流程。

# %%
from google.colab import userdata
from huggingface_hub import login
login(token=userdata.get("HF_TOKEN"))

# %% [markdown]
# 本專案使用 Hugging Face Hub 提供的預訓練大型語言模型，透過 transformers 套件下載並載入 Tokenizer 與 Model。
#
# Tokenizer：負責將輸入文字轉換為模型可處理的 Token ID，並將模型輸出還原為自然語言。
# Model：包含大型語言模型的神經網路架構與預訓練權重，負責執行推論並產生回應。
#
# 在實作過程中，了解 Hugging Face 模型載入流程、Tokenizer 與 Model 的角色，以及預訓練模型的下載、初始化與推論機制，並熟悉 transformers 套件在大型語言模型開發中的基本使用方式。

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.2-3B-Instruct")
model = AutoModelForCausalLM.from_pretrained("meta-llama/Llama-3.2-3B-Instruct")
#如果是 Colab 的免費使用者，可能會無法載入 3B 模型，這個時候可以把 3B 換成 1B
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/878 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/296 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/254 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %% [markdown]
# 另外下載位於此頁面的模型: https://huggingface.co/google/gemma-3-4b-it

# %%
tokenizer2 = AutoTokenizer.from_pretrained("google/gemma-3-4b-it")
model2 = AutoModelForCausalLM.from_pretrained("google/gemma-3-4b-it")
#如果是 Colab 的免費使用者，可能會無法跑第二的模型, 這時請將這個 block 直接註解掉
# Out:
# config.json:   0%|          | 0.00/855 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/33.4M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/35.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/883 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]

# %% [markdown]
# #看 model 中有什麼

# %% [markdown]
# 看載入的模型總共有幾個參數。model是Llama-3.
#
# 2-3B-Instruct，model2是google/gemma-3-4b-it

# %% [markdown]
# ``model.num_parameters()`` 會告訴我們 ``model`` 的參數量

# %%
model.num_parameters() #我們來看看 model (meta-llama/Llama-3.2-3B-Instruct) 的參數量
# Out:
# 3212749824

# %%
model2.num_parameters() #我們來看看 model2 (google/gemma-3-4b-it) 的參數量
# Out:
# 4300079472

# %% [markdown]
# 本專案透過 named_parameters() 檢視大型語言模型中的參數結構，分析各層神經網路的組成方式與參數分布。
#
# 模型參數以 Tensor（張量） 的形式儲存，每個參數皆具有名稱（Name）與形狀（Shape）等資訊。其中，參數名稱可對應至模型架構中的特定模組，例如 Transformer Layer、MLP 或 Attention；參數形狀則反映各層權重矩陣與向量的維度，進一步了解模型的網路結構與資料流向。
#
# 透過分析模型參數，我熟悉了大型語言模型的權重組織方式，並建立對 Transformer 架構、模型層級設計及參數配置的基本理解。

# %%
for name, param in model.named_parameters():
    print(f"{name:80}  |  shape: {tuple(param.shape)}")

#根據輸出，Llama-3.2-3B-Instruct 有幾層呢？
# Out:
# model.embed_tokens.weight                                                         |  shape: (128256, 3072)
# model.layers.0.self_attn.q_proj.weight                                            |  shape: (3072, 3072)
# model.layers.0.self_attn.k_proj.weight                                            |  shape: (1024, 3072)
# model.layers.0.self_attn.v_proj.weight                                            |  shape: (1024, 3072)
# model.layers.0.self_attn.o_proj.weight                                            |  shape: (3072, 3072)
# model.layers.0.mlp.gate_proj.weight                                               |  shape: (8192, 3072)
# model.layers.0.mlp.up_proj.weight                                                 |  shape: (8192, 3072)
# model.layers.0.mlp.down_proj.weight                                               |  shape: (3072, 8192)
# model.layers.0.input_layernorm.weight                                             |  shape: (3072,)
# model.layers.0.post_attention_layernorm.weight                                    |  shape: (3072,)
# model.layers.1.self_attn.q_proj.weight                                            |  shape: (3072, 3072)
# model.layers.1.self_attn.k_proj.weight                                            |  shape: (1024, 3072)
# model.layers.1.self_attn.v_proj.weight                                            |  shape: (1024, 3072)
# model.layers.1.self_attn.o_proj.weight                                            |  shape: (3072, 3072)
# model.layers.1.mlp.gate_proj.weight                                               |  shape: (8192, 3072)
# model.layers.1.mlp.up_proj.weight                                                 |  shape: (8192, 3072)
# model.layers.1.mlp.down_proj.weight                                               |  shape: (3072, 8192)
# model.layers.1.input_layernorm.weight                                             |  shape: (3072,)
# model.layers.1.post_attention_layernorm.weight                                    |  shape: (3072,)
# model.layers.2.self_attn.q_proj.weight                                            |  shape: (3072, 3072)
# model.layers.2.self_attn.k_proj.weight                                            |  shape: (1024, 3072)
# model.layers.2.self_attn.v_proj.weight                                            |  shape: (1024, 3072)
# model.layers.2.self_attn.o_proj.weight                                            |  shape: (3072, 3072)
# model.layers.2.mlp.gate_proj.weight                                               |  shape: (8192, 3072)
# model.layers.2.mlp.up_proj.weight                                                 |  shape: (8192, 3072)
# model.layers.2.mlp.down_proj.weight                                               |  shape: (3072, 8192)
# model.layers.2.input_layernorm.weight                                             |  shape: (3072,)
# model.layers.2.post_attention_layernorm.weight                                    |  shape: (3072,)
# model.layers.3.self_attn.q_proj.weight                                            |  shape: (3072, 3072)
# model.layers.3.self_attn.k_proj.weight                                            |  shape: (1024, 3072)
# model.layers.3.self_attn.v_proj.weight                                            |  shape: (1024, 3072)
# model.layers.3.self_attn.o_proj.weight                                            |  shape: (3072, 3072)
# model.layers.3.mlp.gate_proj.weight                                               |  shape: (8192, 3072)
# model.layers.3.mlp.up_proj.weight                                                 |  shape: (8192, 3072)
# model.layers.3.mlp.down_proj.weight                                               |  shape: (3072, 8192)
# model.layers.3.input_layernorm.weight                                             |  shape: (3072,)
# model.layers.3.post_attention_layernorm.weight                                    |  shape: (3072,)
# model.layers.4.self_attn.q_proj.weight                                            |  shape: (3072, 3072)
# model.layers.4.self_attn.k_proj.weight                                            |  shape: (1024, 3072)
# model.layers.4.self_attn.v_proj.weight                                            |  shape: (1024, 3072)
# model.layers.4.self_attn.o_proj.weight                                            |  shape: (3072, 3072)
# model.layers.4.mlp.gate_proj.weight                                               |  shape: (8192, 3072)
# model.layers.4.mlp.up_proj.weight                                                 |  shape: (8192, 3072)
# model.layers.4.mlp.down_proj.weight                                               |  shape: (3072, 8192)
# model.layers.4.input_layernorm.weight                                             |  shape: (3072,)
# model.layers.4.post_attention_layernorm.weight                                    |  shape: (3072,)
# model.layers.5.self_attn.q_proj.weight                                            |  shape: (3072, 3072)
# model.layers.5.self_attn.k_proj.weight                                            |  shape: (1024, 3072)
# model.layers.5.self_attn.v_proj.weight                                            |  shape: (1024, 3072)
# model.layers.5.self_attn.o_proj.weight                                            |  shape: (3072, 3072)
# model.layers.5.mlp.gate_proj.weight                                               |  shape: (8192, 3072)
# model.layers.5.mlp.up_proj.weight                                                 |  shape: (8192, 3072)
# model.layers.5.mlp.down_proj.weight                                               |  shape: (3072, 8192)
# model.layers.5.input_layernorm.weight                                             |  shape: (3072,)
# model.layers.5.post_attention_layernorm.weight                                    |  shape: (3072,)
# model.layers.6.self_attn.q_proj.weight                                            |  shape: (3072, 3072)
# model.layers.6.self_attn.k_proj.weight                                            |  shape: (1024, 3072)
# model.layers.6.self_attn.v_proj.weight                                            |  shape: (1024, 3072)
# model.layers.6.self_attn.o_proj.weight                                            |  shape: (3072, 3072)
# model.layers.6.mlp.gate_proj.weight                                               |  shape: (8192, 3072)
# model.layers.6.mlp.up_proj.weight                                                 |  shape: (8192, 3072)
# model.layers.6.mlp.down_proj.weight                                               |  shape: (3072, 8192)
# model.layers.6.input_layernorm.weight                                             |  shape: (3072,)
# model.layers.6.post_attention_layernorm.weight                                    |  shape: (3072,)
# model.layers.7.self_attn.q_proj.weight                                            |  shape: (3072, 3072)
# model.layers.7.self_attn.k_proj.weight                                            |  shape: (1024, 3072)
# model.layers.7.self_attn.v_proj.weight                                            |  shape: (1024, 3072)
# model.layers.7.self_attn.o_proj.weight                                            |  shape: (3072, 3072)
# model.layers.7.mlp.gate_proj.weight                                               |  shape: (8192, 3072)
# model.layers.7.mlp.up_proj.weight                                                 |  shape: (8192, 3072)
# model.layers.7.mlp.down_proj.weight                                               |  shape: (3072, 8192)
# model.layers.7.input_layernorm.weight                                             |  shape: (3072,)
# model.layers.7.post_attention_layernorm.weight                                    |  shape: (3072,)
# model.layers.8.self_attn.q_proj.weight                                            |  shape: (3072, 3072)
# model.layers.8.self_attn.k_proj.weight                                            |  shape: (1024, 3072)
# model.layers.8.self_attn.v_proj.weight                                            |  shape: (1024, 3072)
# model.layers.8.self_attn.o_proj.weight                                            |  shape: (3072, 3072)
# model.layers.8.mlp.gate_proj.weight                                               |  shape: (8192, 3072)
# model.layers.8.mlp.up_proj.weight                                                 |  shape: (8192, 3072)
# model.layers.8.mlp.down_proj.weight                                               |  shape: (3072, 8192)
# model.layers.8.input_layernorm.weight                                             |  shape: (3072,)
# model.layers.8.post_attention_layernorm.weight                                    |  shape: (3072,)
# model.layers.9.self_attn.q_proj.weight                                            |  shape: (3072, 3072)
# model.layers.9.self_attn.k_proj.weight                                            |  shape: (1024, 3072)
# model.layers.9.self_attn.v_proj.weight                                            |  shape: (1024, 3072)
# model.layers.9.self_attn.o_proj.weight                                            |  shape: (3072, 3072)
# model.layers.9.mlp.gate_proj.weight                                               |  shape: (8192, 3072)
# model.layers.9.mlp.up_proj.weight                                                 |  shape: (8192, 3072)
# model.layers.9.mlp.down_proj.weight                                               |  shape: (3072, 8192)
# model.layers.9.input_layernorm.weight                                             |  shape: (3072,)
# model.layers.9.post_attention_layernorm.weight                                    |  shape: (3072,)
# model.layers.10.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.10.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.10.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.10.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.10.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.10.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.10.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.10.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.10.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.11.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.11.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.11.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.11.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.11.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.11.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.11.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.11.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.11.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.12.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.12.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.12.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.12.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.12.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.12.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.12.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.12.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.12.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.13.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.13.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.13.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.13.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.13.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.13.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.13.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.13.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.13.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.14.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.14.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.14.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.14.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.14.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.14.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.14.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.14.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.14.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.15.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.15.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.15.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.15.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.15.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.15.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.15.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.15.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.15.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.16.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.16.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.16.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.16.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.16.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.16.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.16.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.16.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.16.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.17.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.17.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.17.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.17.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.17.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.17.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.17.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.17.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.17.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.18.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.18.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.18.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.18.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.18.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.18.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.18.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.18.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.18.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.19.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.19.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.19.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.19.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.19.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.19.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.19.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.19.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.19.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.20.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.20.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.20.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.20.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.20.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.20.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.20.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.20.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.20.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.21.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.21.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.21.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.21.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.21.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.21.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.21.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.21.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.21.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.22.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.22.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.22.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.22.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.22.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.22.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.22.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.22.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.22.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.23.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.23.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.23.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.23.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.23.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.23.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.23.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.23.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.23.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.24.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.24.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.24.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.24.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.24.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.24.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.24.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.24.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.24.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.25.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.25.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.25.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.25.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.25.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.25.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.25.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.25.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.25.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.26.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.26.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.26.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.26.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.26.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.26.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.26.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.26.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.26.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.layers.27.self_attn.q_proj.weight                                           |  shape: (3072, 3072)
# model.layers.27.self_attn.k_proj.weight                                           |  shape: (1024, 3072)
# model.layers.27.self_attn.v_proj.weight                                           |  shape: (1024, 3072)
# model.layers.27.self_attn.o_proj.weight                                           |  shape: (3072, 3072)
# model.layers.27.mlp.gate_proj.weight                                              |  shape: (8192, 3072)
# model.layers.27.mlp.up_proj.weight                                                |  shape: (8192, 3072)
# model.layers.27.mlp.down_proj.weight                                              |  shape: (3072, 8192)
# model.layers.27.input_layernorm.weight                                            |  shape: (3072,)
# model.layers.27.post_attention_layernorm.weight                                   |  shape: (3072,)
# model.norm.weight                                                                 |  shape: (3072,)

# %%
for name, param in model2.named_parameters():
    print(f"{name:80}  |  shape: {tuple(param.shape)}")

#比較看看，model (Llama-3.2-3B-Instruct) 和 model 2 (google/gemma-3-4b-it) 有什麼不同？
# Out:
# model.vision_tower.vision_model.embeddings.patch_embedding.weight                 |  shape: (1152, 3, 14, 14)
# model.vision_tower.vision_model.embeddings.patch_embedding.bias                   |  shape: (1152,)
# model.vision_tower.vision_model.embeddings.position_embedding.weight              |  shape: (4096, 1152)
# model.vision_tower.vision_model.encoder.layers.0.layer_norm1.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.0.layer_norm1.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.0.self_attn.k_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.0.self_attn.k_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.0.self_attn.v_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.0.self_attn.v_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.0.self_attn.q_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.0.self_attn.q_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.0.self_attn.out_proj.weight        |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.0.self_attn.out_proj.bias          |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.0.layer_norm2.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.0.layer_norm2.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.0.mlp.fc1.weight                   |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.0.mlp.fc1.bias                     |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.0.mlp.fc2.weight                   |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.0.mlp.fc2.bias                     |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.1.layer_norm1.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.1.layer_norm1.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.1.self_attn.k_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.1.self_attn.k_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.1.self_attn.v_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.1.self_attn.v_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.1.self_attn.q_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.1.self_attn.q_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.1.self_attn.out_proj.weight        |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.1.self_attn.out_proj.bias          |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.1.layer_norm2.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.1.layer_norm2.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.1.mlp.fc1.weight                   |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.1.mlp.fc1.bias                     |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.1.mlp.fc2.weight                   |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.1.mlp.fc2.bias                     |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.2.layer_norm1.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.2.layer_norm1.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.2.self_attn.k_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.2.self_attn.k_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.2.self_attn.v_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.2.self_attn.v_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.2.self_attn.q_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.2.self_attn.q_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.2.self_attn.out_proj.weight        |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.2.self_attn.out_proj.bias          |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.2.layer_norm2.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.2.layer_norm2.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.2.mlp.fc1.weight                   |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.2.mlp.fc1.bias                     |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.2.mlp.fc2.weight                   |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.2.mlp.fc2.bias                     |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.3.layer_norm1.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.3.layer_norm1.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.3.self_attn.k_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.3.self_attn.k_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.3.self_attn.v_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.3.self_attn.v_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.3.self_attn.q_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.3.self_attn.q_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.3.self_attn.out_proj.weight        |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.3.self_attn.out_proj.bias          |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.3.layer_norm2.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.3.layer_norm2.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.3.mlp.fc1.weight                   |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.3.mlp.fc1.bias                     |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.3.mlp.fc2.weight                   |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.3.mlp.fc2.bias                     |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.4.layer_norm1.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.4.layer_norm1.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.4.self_attn.k_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.4.self_attn.k_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.4.self_attn.v_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.4.self_attn.v_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.4.self_attn.q_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.4.self_attn.q_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.4.self_attn.out_proj.weight        |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.4.self_attn.out_proj.bias          |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.4.layer_norm2.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.4.layer_norm2.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.4.mlp.fc1.weight                   |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.4.mlp.fc1.bias                     |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.4.mlp.fc2.weight                   |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.4.mlp.fc2.bias                     |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.5.layer_norm1.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.5.layer_norm1.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.5.self_attn.k_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.5.self_attn.k_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.5.self_attn.v_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.5.self_attn.v_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.5.self_attn.q_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.5.self_attn.q_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.5.self_attn.out_proj.weight        |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.5.self_attn.out_proj.bias          |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.5.layer_norm2.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.5.layer_norm2.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.5.mlp.fc1.weight                   |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.5.mlp.fc1.bias                     |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.5.mlp.fc2.weight                   |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.5.mlp.fc2.bias                     |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.6.layer_norm1.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.6.layer_norm1.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.6.self_attn.k_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.6.self_attn.k_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.6.self_attn.v_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.6.self_attn.v_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.6.self_attn.q_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.6.self_attn.q_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.6.self_attn.out_proj.weight        |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.6.self_attn.out_proj.bias          |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.6.layer_norm2.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.6.layer_norm2.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.6.mlp.fc1.weight                   |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.6.mlp.fc1.bias                     |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.6.mlp.fc2.weight                   |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.6.mlp.fc2.bias                     |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.7.layer_norm1.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.7.layer_norm1.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.7.self_attn.k_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.7.self_attn.k_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.7.self_attn.v_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.7.self_attn.v_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.7.self_attn.q_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.7.self_attn.q_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.7.self_attn.out_proj.weight        |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.7.self_attn.out_proj.bias          |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.7.layer_norm2.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.7.layer_norm2.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.7.mlp.fc1.weight                   |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.7.mlp.fc1.bias                     |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.7.mlp.fc2.weight                   |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.7.mlp.fc2.bias                     |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.8.layer_norm1.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.8.layer_norm1.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.8.self_attn.k_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.8.self_attn.k_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.8.self_attn.v_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.8.self_attn.v_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.8.self_attn.q_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.8.self_attn.q_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.8.self_attn.out_proj.weight        |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.8.self_attn.out_proj.bias          |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.8.layer_norm2.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.8.layer_norm2.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.8.mlp.fc1.weight                   |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.8.mlp.fc1.bias                     |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.8.mlp.fc2.weight                   |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.8.mlp.fc2.bias                     |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.9.layer_norm1.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.9.layer_norm1.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.9.self_attn.k_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.9.self_attn.k_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.9.self_attn.v_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.9.self_attn.v_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.9.self_attn.q_proj.weight          |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.9.self_attn.q_proj.bias            |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.9.self_attn.out_proj.weight        |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.9.self_attn.out_proj.bias          |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.9.layer_norm2.weight               |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.9.layer_norm2.bias                 |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.9.mlp.fc1.weight                   |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.9.mlp.fc1.bias                     |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.9.mlp.fc2.weight                   |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.9.mlp.fc2.bias                     |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.10.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.10.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.10.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.10.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.10.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.10.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.10.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.10.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.10.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.10.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.10.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.10.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.10.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.10.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.10.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.10.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.11.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.11.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.11.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.11.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.11.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.11.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.11.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.11.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.11.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.11.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.11.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.11.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.11.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.11.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.11.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.11.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.12.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.12.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.12.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.12.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.12.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.12.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.12.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.12.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.12.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.12.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.12.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.12.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.12.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.12.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.12.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.12.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.13.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.13.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.13.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.13.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.13.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.13.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.13.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.13.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.13.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.13.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.13.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.13.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.13.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.13.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.13.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.13.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.14.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.14.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.14.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.14.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.14.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.14.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.14.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.14.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.14.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.14.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.14.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.14.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.14.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.14.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.14.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.14.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.15.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.15.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.15.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.15.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.15.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.15.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.15.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.15.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.15.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.15.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.15.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.15.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.15.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.15.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.15.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.15.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.16.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.16.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.16.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.16.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.16.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.16.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.16.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.16.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.16.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.16.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.16.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.16.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.16.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.16.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.16.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.16.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.17.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.17.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.17.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.17.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.17.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.17.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.17.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.17.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.17.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.17.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.17.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.17.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.17.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.17.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.17.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.17.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.18.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.18.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.18.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.18.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.18.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.18.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.18.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.18.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.18.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.18.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.18.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.18.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.18.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.18.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.18.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.18.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.19.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.19.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.19.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.19.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.19.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.19.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.19.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.19.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.19.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.19.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.19.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.19.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.19.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.19.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.19.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.19.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.20.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.20.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.20.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.20.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.20.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.20.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.20.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.20.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.20.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.20.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.20.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.20.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.20.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.20.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.20.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.20.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.21.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.21.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.21.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.21.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.21.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.21.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.21.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.21.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.21.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.21.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.21.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.21.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.21.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.21.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.21.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.21.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.22.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.22.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.22.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.22.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.22.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.22.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.22.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.22.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.22.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.22.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.22.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.22.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.22.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.22.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.22.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.22.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.23.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.23.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.23.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.23.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.23.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.23.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.23.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.23.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.23.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.23.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.23.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.23.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.23.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.23.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.23.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.23.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.24.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.24.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.24.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.24.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.24.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.24.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.24.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.24.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.24.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.24.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.24.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.24.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.24.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.24.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.24.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.24.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.25.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.25.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.25.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.25.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.25.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.25.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.25.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.25.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.25.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.25.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.25.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.25.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.25.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.25.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.25.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.25.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.26.layer_norm1.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.26.layer_norm1.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.26.self_attn.k_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.26.self_attn.k_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.26.self_attn.v_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.26.self_attn.v_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.26.self_attn.q_proj.weight         |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.26.self_attn.q_proj.bias           |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.26.self_attn.out_proj.weight       |  shape: (1152, 1152)
# model.vision_tower.vision_model.encoder.layers.26.self_attn.out_proj.bias         |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.26.layer_norm2.weight              |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.26.layer_norm2.bias                |  shape: (1152,)
# model.vision_tower.vision_model.encoder.layers.26.mlp.fc1.weight                  |  shape: (4304, 1152)
# model.vision_tower.vision_model.encoder.layers.26.mlp.fc1.bias                    |  shape: (4304,)
# model.vision_tower.vision_model.encoder.layers.26.mlp.fc2.weight                  |  shape: (1152, 4304)
# model.vision_tower.vision_model.encoder.layers.26.mlp.fc2.bias                    |  shape: (1152,)
# model.vision_tower.vision_model.post_layernorm.weight                             |  shape: (1152,)
# model.vision_tower.vision_model.post_layernorm.bias                               |  shape: (1152,)
# model.multi_modal_projector.mm_input_projection_weight                            |  shape: (1152, 2560)
# model.multi_modal_projector.mm_soft_emb_norm.weight                               |  shape: (1152,)
# model.language_model.embed_tokens.weight                                          |  shape: (262208, 2560)
# model.language_model.layers.0.self_attn.q_proj.weight                             |  shape: (2048, 2560)
# model.language_model.layers.0.self_attn.k_proj.weight                             |  shape: (1024, 2560)
# model.language_model.layers.0.self_attn.v_proj.weight                             |  shape: (1024, 2560)
# model.language_model.layers.0.self_attn.o_proj.weight                             |  shape: (2560, 2048)
# model.language_model.layers.0.self_attn.q_norm.weight                             |  shape: (256,)
# model.language_model.layers.0.self_attn.k_norm.weight                             |  shape: (256,)
# model.language_model.layers.0.mlp.gate_proj.weight                                |  shape: (10240, 2560)
# model.language_model.layers.0.mlp.up_proj.weight                                  |  shape: (10240, 2560)
# model.language_model.layers.0.mlp.down_proj.weight                                |  shape: (2560, 10240)
# model.language_model.layers.0.input_layernorm.weight                              |  shape: (2560,)
# model.language_model.layers.0.post_attention_layernorm.weight                     |  shape: (2560,)
# model.language_model.layers.0.pre_feedforward_layernorm.weight                    |  shape: (2560,)
# model.language_model.layers.0.post_feedforward_layernorm.weight                   |  shape: (2560,)
# model.language_model.layers.1.self_attn.q_proj.weight                             |  shape: (2048, 2560)
# model.language_model.layers.1.self_attn.k_proj.weight                             |  shape: (1024, 2560)
# model.language_model.layers.1.self_attn.v_proj.weight                             |  shape: (1024, 2560)
# model.language_model.layers.1.self_attn.o_proj.weight                             |  shape: (2560, 2048)
# model.language_model.layers.1.self_attn.q_norm.weight                             |  shape: (256,)
# model.language_model.layers.1.self_attn.k_norm.weight                             |  shape: (256,)
# model.language_model.layers.1.mlp.gate_proj.weight                                |  shape: (10240, 2560)
# model.language_model.layers.1.mlp.up_proj.weight                                  |  shape: (10240, 2560)
# model.language_model.layers.1.mlp.down_proj.weight                                |  shape: (2560, 10240)
# model.language_model.layers.1.input_layernorm.weight                              |  shape: (2560,)
# model.language_model.layers.1.post_attention_layernorm.weight                     |  shape: (2560,)
# model.language_model.layers.1.pre_feedforward_layernorm.weight                    |  shape: (2560,)
# model.language_model.layers.1.post_feedforward_layernorm.weight                   |  shape: (2560,)
# model.language_model.layers.2.self_attn.q_proj.weight                             |  shape: (2048, 2560)
# model.language_model.layers.2.self_attn.k_proj.weight                             |  shape: (1024, 2560)
# model.language_model.layers.2.self_attn.v_proj.weight                             |  shape: (1024, 2560)
# model.language_model.layers.2.self_attn.o_proj.weight                             |  shape: (2560, 2048)
# ...
# model.language_model.layers.22.self_attn.v_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.22.self_attn.o_proj.weight                            |  shape: (2560, 2048)
# model.language_model.layers.22.self_attn.q_norm.weight                            |  shape: (256,)
# model.language_model.layers.22.self_attn.k_norm.weight                            |  shape: (256,)
# model.language_model.layers.22.mlp.gate_proj.weight                               |  shape: (10240, 2560)
# model.language_model.layers.22.mlp.up_proj.weight                                 |  shape: (10240, 2560)
# model.language_model.layers.22.mlp.down_proj.weight                               |  shape: (2560, 10240)
# model.language_model.layers.22.input_layernorm.weight                             |  shape: (2560,)
# model.language_model.layers.22.post_attention_layernorm.weight                    |  shape: (2560,)
# model.language_model.layers.22.pre_feedforward_layernorm.weight                   |  shape: (2560,)
# model.language_model.layers.22.post_feedforward_layernorm.weight                  |  shape: (2560,)
# model.language_model.layers.23.self_attn.q_proj.weight                            |  shape: (2048, 2560)
# model.language_model.layers.23.self_attn.k_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.23.self_attn.v_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.23.self_attn.o_proj.weight                            |  shape: (2560, 2048)
# model.language_model.layers.23.self_attn.q_norm.weight                            |  shape: (256,)
# model.language_model.layers.23.self_attn.k_norm.weight                            |  shape: (256,)
# model.language_model.layers.23.mlp.gate_proj.weight                               |  shape: (10240, 2560)
# model.language_model.layers.23.mlp.up_proj.weight                                 |  shape: (10240, 2560)
# model.language_model.layers.23.mlp.down_proj.weight                               |  shape: (2560, 10240)
# model.language_model.layers.23.input_layernorm.weight                             |  shape: (2560,)
# model.language_model.layers.23.post_attention_layernorm.weight                    |  shape: (2560,)
# model.language_model.layers.23.pre_feedforward_layernorm.weight                   |  shape: (2560,)
# model.language_model.layers.23.post_feedforward_layernorm.weight                  |  shape: (2560,)
# model.language_model.layers.24.self_attn.q_proj.weight                            |  shape: (2048, 2560)
# model.language_model.layers.24.self_attn.k_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.24.self_attn.v_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.24.self_attn.o_proj.weight                            |  shape: (2560, 2048)
# model.language_model.layers.24.self_attn.q_norm.weight                            |  shape: (256,)
# model.language_model.layers.24.self_attn.k_norm.weight                            |  shape: (256,)
# model.language_model.layers.24.mlp.gate_proj.weight                               |  shape: (10240, 2560)
# model.language_model.layers.24.mlp.up_proj.weight                                 |  shape: (10240, 2560)
# model.language_model.layers.24.mlp.down_proj.weight                               |  shape: (2560, 10240)
# model.language_model.layers.24.input_layernorm.weight                             |  shape: (2560,)
# model.language_model.layers.24.post_attention_layernorm.weight                    |  shape: (2560,)
# model.language_model.layers.24.pre_feedforward_layernorm.weight                   |  shape: (2560,)
# model.language_model.layers.24.post_feedforward_layernorm.weight                  |  shape: (2560,)
# model.language_model.layers.25.self_attn.q_proj.weight                            |  shape: (2048, 2560)
# model.language_model.layers.25.self_attn.k_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.25.self_attn.v_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.25.self_attn.o_proj.weight                            |  shape: (2560, 2048)
# model.language_model.layers.25.self_attn.q_norm.weight                            |  shape: (256,)
# model.language_model.layers.25.self_attn.k_norm.weight                            |  shape: (256,)
# model.language_model.layers.25.mlp.gate_proj.weight                               |  shape: (10240, 2560)
# model.language_model.layers.25.mlp.up_proj.weight                                 |  shape: (10240, 2560)
# model.language_model.layers.25.mlp.down_proj.weight                               |  shape: (2560, 10240)
# model.language_model.layers.25.input_layernorm.weight                             |  shape: (2560,)
# model.language_model.layers.25.post_attention_layernorm.weight                    |  shape: (2560,)
# model.language_model.layers.25.pre_feedforward_layernorm.weight                   |  shape: (2560,)
# model.language_model.layers.25.post_feedforward_layernorm.weight                  |  shape: (2560,)
# model.language_model.layers.26.self_attn.q_proj.weight                            |  shape: (2048, 2560)
# model.language_model.layers.26.self_attn.k_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.26.self_attn.v_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.26.self_attn.o_proj.weight                            |  shape: (2560, 2048)
# model.language_model.layers.26.self_attn.q_norm.weight                            |  shape: (256,)
# model.language_model.layers.26.self_attn.k_norm.weight                            |  shape: (256,)
# model.language_model.layers.26.mlp.gate_proj.weight                               |  shape: (10240, 2560)
# model.language_model.layers.26.mlp.up_proj.weight                                 |  shape: (10240, 2560)
# model.language_model.layers.26.mlp.down_proj.weight                               |  shape: (2560, 10240)
# model.language_model.layers.26.input_layernorm.weight                             |  shape: (2560,)
# model.language_model.layers.26.post_attention_layernorm.weight                    |  shape: (2560,)
# model.language_model.layers.26.pre_feedforward_layernorm.weight                   |  shape: (2560,)
# model.language_model.layers.26.post_feedforward_layernorm.weight                  |  shape: (2560,)
# model.language_model.layers.27.self_attn.q_proj.weight                            |  shape: (2048, 2560)
# model.language_model.layers.27.self_attn.k_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.27.self_attn.v_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.27.self_attn.o_proj.weight                            |  shape: (2560, 2048)
# model.language_model.layers.27.self_attn.q_norm.weight                            |  shape: (256,)
# model.language_model.layers.27.self_attn.k_norm.weight                            |  shape: (256,)
# model.language_model.layers.27.mlp.gate_proj.weight                               |  shape: (10240, 2560)
# model.language_model.layers.27.mlp.up_proj.weight                                 |  shape: (10240, 2560)
# model.language_model.layers.27.mlp.down_proj.weight                               |  shape: (2560, 10240)
# model.language_model.layers.27.input_layernorm.weight                             |  shape: (2560,)
# model.language_model.layers.27.post_attention_layernorm.weight                    |  shape: (2560,)
# model.language_model.layers.27.pre_feedforward_layernorm.weight                   |  shape: (2560,)
# model.language_model.layers.27.post_feedforward_layernorm.weight                  |  shape: (2560,)
# model.language_model.layers.28.self_attn.q_proj.weight                            |  shape: (2048, 2560)
# model.language_model.layers.28.self_attn.k_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.28.self_attn.v_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.28.self_attn.o_proj.weight                            |  shape: (2560, 2048)
# model.language_model.layers.28.self_attn.q_norm.weight                            |  shape: (256,)
# model.language_model.layers.28.self_attn.k_norm.weight                            |  shape: (256,)
# model.language_model.layers.28.mlp.gate_proj.weight                               |  shape: (10240, 2560)
# model.language_model.layers.28.mlp.up_proj.weight                                 |  shape: (10240, 2560)
# model.language_model.layers.28.mlp.down_proj.weight                               |  shape: (2560, 10240)
# model.language_model.layers.28.input_layernorm.weight                             |  shape: (2560,)
# model.language_model.layers.28.post_attention_layernorm.weight                    |  shape: (2560,)
# model.language_model.layers.28.pre_feedforward_layernorm.weight                   |  shape: (2560,)
# model.language_model.layers.28.post_feedforward_layernorm.weight                  |  shape: (2560,)
# model.language_model.layers.29.self_attn.q_proj.weight                            |  shape: (2048, 2560)
# model.language_model.layers.29.self_attn.k_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.29.self_attn.v_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.29.self_attn.o_proj.weight                            |  shape: (2560, 2048)
# model.language_model.layers.29.self_attn.q_norm.weight                            |  shape: (256,)
# model.language_model.layers.29.self_attn.k_norm.weight                            |  shape: (256,)
# model.language_model.layers.29.mlp.gate_proj.weight                               |  shape: (10240, 2560)
# model.language_model.layers.29.mlp.up_proj.weight                                 |  shape: (10240, 2560)
# model.language_model.layers.29.mlp.down_proj.weight                               |  shape: (2560, 10240)
# model.language_model.layers.29.input_layernorm.weight                             |  shape: (2560,)
# model.language_model.layers.29.post_attention_layernorm.weight                    |  shape: (2560,)
# model.language_model.layers.29.pre_feedforward_layernorm.weight                   |  shape: (2560,)
# model.language_model.layers.29.post_feedforward_layernorm.weight                  |  shape: (2560,)
# model.language_model.layers.30.self_attn.q_proj.weight                            |  shape: (2048, 2560)
# model.language_model.layers.30.self_attn.k_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.30.self_attn.v_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.30.self_attn.o_proj.weight                            |  shape: (2560, 2048)
# model.language_model.layers.30.self_attn.q_norm.weight                            |  shape: (256,)
# model.language_model.layers.30.self_attn.k_norm.weight                            |  shape: (256,)
# model.language_model.layers.30.mlp.gate_proj.weight                               |  shape: (10240, 2560)
# model.language_model.layers.30.mlp.up_proj.weight                                 |  shape: (10240, 2560)
# model.language_model.layers.30.mlp.down_proj.weight                               |  shape: (2560, 10240)
# model.language_model.layers.30.input_layernorm.weight                             |  shape: (2560,)
# model.language_model.layers.30.post_attention_layernorm.weight                    |  shape: (2560,)
# model.language_model.layers.30.pre_feedforward_layernorm.weight                   |  shape: (2560,)
# model.language_model.layers.30.post_feedforward_layernorm.weight                  |  shape: (2560,)
# model.language_model.layers.31.self_attn.q_proj.weight                            |  shape: (2048, 2560)
# model.language_model.layers.31.self_attn.k_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.31.self_attn.v_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.31.self_attn.o_proj.weight                            |  shape: (2560, 2048)
# model.language_model.layers.31.self_attn.q_norm.weight                            |  shape: (256,)
# model.language_model.layers.31.self_attn.k_norm.weight                            |  shape: (256,)
# model.language_model.layers.31.mlp.gate_proj.weight                               |  shape: (10240, 2560)
# model.language_model.layers.31.mlp.up_proj.weight                                 |  shape: (10240, 2560)
# model.language_model.layers.31.mlp.down_proj.weight                               |  shape: (2560, 10240)
# model.language_model.layers.31.input_layernorm.weight                             |  shape: (2560,)
# model.language_model.layers.31.post_attention_layernorm.weight                    |  shape: (2560,)
# model.language_model.layers.31.pre_feedforward_layernorm.weight                   |  shape: (2560,)
# model.language_model.layers.31.post_feedforward_layernorm.weight                  |  shape: (2560,)
# model.language_model.layers.32.self_attn.q_proj.weight                            |  shape: (2048, 2560)
# model.language_model.layers.32.self_attn.k_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.32.self_attn.v_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.32.self_attn.o_proj.weight                            |  shape: (2560, 2048)
# model.language_model.layers.32.self_attn.q_norm.weight                            |  shape: (256,)
# model.language_model.layers.32.self_attn.k_norm.weight                            |  shape: (256,)
# model.language_model.layers.32.mlp.gate_proj.weight                               |  shape: (10240, 2560)
# model.language_model.layers.32.mlp.up_proj.weight                                 |  shape: (10240, 2560)
# model.language_model.layers.32.mlp.down_proj.weight                               |  shape: (2560, 10240)
# model.language_model.layers.32.input_layernorm.weight                             |  shape: (2560,)
# model.language_model.layers.32.post_attention_layernorm.weight                    |  shape: (2560,)
# model.language_model.layers.32.pre_feedforward_layernorm.weight                   |  shape: (2560,)
# model.language_model.layers.32.post_feedforward_layernorm.weight                  |  shape: (2560,)
# model.language_model.layers.33.self_attn.q_proj.weight                            |  shape: (2048, 2560)
# model.language_model.layers.33.self_attn.k_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.33.self_attn.v_proj.weight                            |  shape: (1024, 2560)
# model.language_model.layers.33.self_attn.o_proj.weight                            |  shape: (2560, 2048)
# model.language_model.layers.33.self_attn.q_norm.weight                            |  shape: (256,)
# model.language_model.layers.33.self_attn.k_norm.weight                            |  shape: (256,)
# model.language_model.layers.33.mlp.gate_proj.weight                               |  shape: (10240, 2560)
# model.language_model.layers.33.mlp.up_proj.weight                                 |  shape: (10240, 2560)
# model.language_model.layers.33.mlp.down_proj.weight                               |  shape: (2560, 10240)
# model.language_model.layers.33.input_layernorm.weight                             |  shape: (2560,)
# model.language_model.layers.33.post_attention_layernorm.weight                    |  shape: (2560,)
# model.language_model.layers.33.pre_feedforward_layernorm.weight                   |  shape: (2560,)
# model.language_model.layers.33.post_feedforward_layernorm.weight                  |  shape: (2560,)
# model.language_model.norm.weight                                                  |  shape: (2560,)

# %% [markdown]
# 用 `model.state_dict()` 把實際參數拿出來看看

# %%
model.state_dict()
# Out:
# OrderedDict([('model.embed_tokens.weight',
#               tensor([[ 1.1292e-02,  9.9487e-03,  1.4160e-02,  ..., -3.5706e-03,
#                        -1.9775e-02,  5.3711e-03],
#                       [ 1.3245e-02, -3.8385e-05,  2.2461e-02,  ..., -2.6550e-03,
#                         3.1738e-02, -1.0681e-03],
#                       [ 1.9775e-02,  2.0020e-02,  2.8687e-02,  ..., -3.5248e-03,
#                         3.1433e-03, -7.6294e-03],
#                       ...,
#                       [-3.0975e-03,  2.1057e-03,  4.8828e-03,  ..., -2.0905e-03,
#                        -1.2207e-03, -2.8992e-03],
#                       [-3.0975e-03,  2.1057e-03,  4.8828e-03,  ..., -2.0905e-03,
#                        -1.2207e-03, -2.8992e-03],
#                       [-3.0975e-03,  2.1057e-03,  4.8828e-03,  ..., -2.0905e-03,
#                        -1.2207e-03, -2.8992e-03]], dtype=torch.bfloat16)),
#              ('model.layers.0.self_attn.q_proj.weight',
#               tensor([[-0.0327,  0.0297,  0.0645,  ...,  0.0835, -0.0356, -0.0197],
#                       [-0.0099, -0.0227,  0.0439,  ...,  0.0525, -0.0053, -0.0349],
#                       [ 0.0214,  0.0134,  0.0352,  ...,  0.0503, -0.0415, -0.0129],
#                       ...,
#                       [ 0.0021, -0.0085,  0.0615,  ..., -0.0105,  0.0020,  0.0067],
#                       [ 0.0079, -0.0128,  0.0205,  ..., -0.0103, -0.0214,  0.0051],
#                       [-0.0085,  0.0251, -0.0089,  ...,  0.0081,  0.0053, -0.0081]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.0.self_attn.k_proj.weight',
#               tensor([[ 0.0054, -0.1133,  0.0625,  ..., -0.0222, -0.0781,  0.0044],
#                       [ 0.0080, -0.0615,  0.0442,  ..., -0.0410, -0.0210, -0.0299],
#                       [-0.0050, -0.0659,  0.0791,  ..., -0.0151, -0.0134,  0.0222],
#                       ...,
#                       [ 0.0132,  0.0220, -0.0410,  ..., -0.0242,  0.0139,  0.0052],
#                       [ 0.0097,  0.0144,  0.0435,  ...,  0.0194,  0.0337,  0.0334],
#                       [ 0.0008, -0.0153,  0.0747,  ...,  0.0204, -0.0791,  0.0090]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.0.self_attn.v_proj.weight',
#               tensor([[ 1.5259e-02,  6.1035e-03,  2.5940e-03,  ..., -1.4648e-02,
#                        -1.0437e-02,  2.0142e-02],
#                       [ 6.7139e-03, -2.2583e-03, -5.2643e-04,  ..., -2.2949e-02,
#                        -1.2589e-03,  1.3550e-02],
#                       [ 6.9580e-03, -7.0496e-03,  5.6458e-03,  ..., -1.0986e-02,
#                        -9.8267e-03, -1.4709e-02],
#                       ...,
#                       [-7.3624e-04,  2.5146e-02,  6.8665e-04,  ..., -1.7090e-02,
#                         1.1253e-04,  2.8534e-03],
#                       [ 6.8970e-03,  5.8594e-03,  3.9673e-03,  ..., -7.1106e-03,
#                         2.1515e-03,  3.6163e-03],
#                       [ 4.1199e-03,  3.5553e-03,  1.8239e-05,  ...,  7.2021e-03,
#                        -1.8845e-03, -3.6163e-03]], dtype=torch.bfloat16)),
#              ('model.layers.0.self_attn.o_proj.weight',
#               tensor([[ 5.4932e-03,  8.2779e-04,  6.8970e-03,  ..., -1.5869e-03,
#                         9.6436e-03,  1.3916e-02],
#                       [ 7.1411e-03,  6.6833e-03,  4.8218e-03,  ...,  7.0496e-03,
#                         5.7220e-04,  3.3140e-05],
#                       [ 3.8605e-03, -8.6060e-03,  4.9591e-04,  ...,  3.5156e-02,
#                        -5.0964e-03, -1.8845e-03],
#                       ...,
#                       [ 4.8523e-03, -7.1106e-03,  1.0147e-03,  ...,  4.8218e-03,
#                         1.1536e-02, -1.3611e-02],
#                       [ 2.2705e-02, -8.8501e-03,  1.6113e-02,  ..., -3.7689e-03,
#                        -2.8534e-03, -4.5471e-03],
#                       [ 1.1353e-02, -5.2185e-03,  6.5613e-03,  ...,  1.4832e-02,
#                         1.0193e-02,  1.3367e-02]], dtype=torch.bfloat16)),
#              ('model.layers.0.mlp.gate_proj.weight',
#               tensor([[-0.0030, -0.0048,  0.0199,  ...,  0.0325, -0.0110,  0.0100],
#                       [ 0.0023,  0.0072,  0.0442,  ...,  0.0278, -0.0040, -0.0076],
#                       [ 0.0356, -0.0156,  0.0221,  ..., -0.0371, -0.0171, -0.0007],
#                       ...,
#                       [ 0.0019, -0.0056, -0.0193,  ...,  0.0420,  0.0352,  0.0265],
#                       [ 0.0072, -0.0154,  0.0056,  ...,  0.0022,  0.0302,  0.0059],
#                       [ 0.0278,  0.0101,  0.0055,  ..., -0.0048,  0.0139, -0.0405]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.0.mlp.up_proj.weight',
#               tensor([[-0.0096,  0.0151, -0.0020,  ...,  0.0206, -0.0053,  0.0076],
#                       [-0.0058,  0.0148, -0.0179,  ..., -0.0286, -0.0181,  0.0061],
#                       [-0.0090, -0.0117,  0.0260,  ...,  0.0051, -0.0081, -0.0109],
#                       ...,
#                       [-0.0272,  0.0016,  0.0057,  ..., -0.0060,  0.0001, -0.0192],
#                       [ 0.0188,  0.0112,  0.0104,  ...,  0.0090,  0.0145, -0.0178],
#                       [-0.0164,  0.0144,  0.0002,  ..., -0.0081, -0.0139, -0.0170]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.0.mlp.down_proj.weight',
#               tensor([[ 0.0089, -0.0128, -0.0198,  ...,  0.0043,  0.0222,  0.0140],
#                       [ 0.0165, -0.0047, -0.0003,  ...,  0.0001, -0.0182,  0.0111],
#                       [ 0.0229, -0.0053,  0.0269,  ...,  0.0058,  0.0153, -0.0200],
#                       ...,
#                       [-0.0144, -0.0258,  0.0162,  ..., -0.0029, -0.0344, -0.0234],
#                       [-0.0060, -0.0110, -0.0325,  ...,  0.0195,  0.0107, -0.0190],
#                       [-0.0206,  0.0067, -0.0220,  ...,  0.0312, -0.0176, -0.0132]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.0.input_layernorm.weight',
#               tensor([0.0645, 0.0977, 0.3945,  ..., 0.0820, 0.0601, 0.0505],
#                      dtype=torch.bfloat16)),
#              ('model.layers.0.post_attention_layernorm.weight',
#               tensor([0.1406, 0.1396, 0.1445,  ..., 0.1367, 0.1377, 0.1367],
#                      dtype=torch.bfloat16)),
#              ('model.layers.1.self_attn.q_proj.weight',
#               tensor([[-0.0613, -0.0220, -0.0193,  ..., -0.0226,  0.0107, -0.0009],
#                       [ 0.0038, -0.0042,  0.0366,  ..., -0.0122,  0.0190,  0.0068],
#                       [-0.0075,  0.0121,  0.0337,  ..., -0.0015,  0.0295,  0.0109],
#                       ...,
#                       [ 0.0437, -0.0061, -0.0084,  ...,  0.0332,  0.0167, -0.0522],
#                       [ 0.0277, -0.0203,  0.0133,  ...,  0.0189,  0.0030,  0.0579],
#                       [ 0.0859,  0.0415,  0.0166,  ..., -0.0889,  0.0126, -0.0085]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.1.self_attn.k_proj.weight',
#               tensor([[-0.0942, -0.0186,  0.0078,  ..., -0.1016, -0.0225, -0.0023],
#                       [-0.0069,  0.0518,  0.0294,  ..., -0.0410, -0.0214, -0.0144],
#                       [-0.0096, -0.0188,  0.0087,  ..., -0.0403, -0.0171, -0.0040],
#                       ...,
#                       [ 0.0403, -0.0007, -0.0178,  ..., -0.0420,  0.0076, -0.0223],
#                       [ 0.0767, -0.0129,  0.0264,  ..., -0.0045, -0.0310,  0.0376],
#                       [ 0.0684,  0.0408,  0.0723,  ..., -0.0283, -0.0023,  0.0021]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.1.self_attn.v_proj.weight',
#               tensor([[-0.0168, -0.0168, -0.0017,  ...,  0.0049, -0.0061,  0.0125],
#                       [ 0.0104,  0.0006,  0.0015,  ..., -0.0025, -0.0026,  0.0045],
#                       [-0.0222, -0.0110, -0.0062,  ..., -0.0062, -0.0256, -0.0035],
#                       ...,
#                       [ 0.0146,  0.0023,  0.0014,  ..., -0.0019,  0.0120, -0.0243],
#                       [ 0.0089,  0.0125,  0.0067,  ..., -0.0093,  0.0342, -0.0192],
#                       [ 0.0038,  0.0097,  0.0118,  ..., -0.0061, -0.0057,  0.0204]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.1.self_attn.o_proj.weight',
#               tensor([[ 4.7607e-03,  1.4709e-02,  1.4282e-02,  ..., -2.4414e-02,
#                         1.0315e-02,  3.3875e-03],
#                       [ 8.2397e-03,  2.3193e-02, -4.1962e-05,  ..., -1.8555e-02,
#                        -9.8267e-03,  8.6060e-03],
#                       [-6.0425e-03, -1.5259e-04,  1.2024e-02,  ...,  7.7438e-04,
#                         1.3916e-02,  4.0588e-03],
#                       ...,
#                       [ 1.2756e-02, -2.5513e-02, -1.8799e-02,  ...,  2.3315e-02,
#                         2.9602e-03,  1.7090e-02],
#                       [ 1.7700e-02,  6.1646e-03, -4.1504e-03,  ..., -1.1658e-02,
#                        -1.4282e-02, -6.4850e-04],
#                       [ 2.9297e-02, -4.8218e-03,  7.1106e-03,  ...,  7.0801e-03,
#                         2.1973e-02, -2.7344e-02]], dtype=torch.bfloat16)),
#              ('model.layers.1.mlp.gate_proj.weight',
#               tensor([[-0.0201,  0.0090,  0.0281,  ..., -0.0090,  0.0112, -0.0167],
#                       [-0.0253,  0.0021, -0.0018,  ..., -0.0118, -0.0396, -0.0591],
#                       [-0.0344, -0.0303, -0.0065,  ...,  0.0159,  0.0361, -0.0214],
#                       ...,
#                       [-0.0261,  0.0116, -0.0048,  ..., -0.0043,  0.0089, -0.0102],
#                       [-0.0097,  0.0286,  0.0227,  ...,  0.0157,  0.0325,  0.0197],
#                       [ 0.0115, -0.0117,  0.0308,  ...,  0.0045, -0.0173, -0.0435]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.1.mlp.up_proj.weight',
#               tensor([[ 0.0190,  0.0166,  0.0356,  ..., -0.0099,  0.0366,  0.0096],
#                       [-0.0288,  0.0059,  0.0096,  ...,  0.0030, -0.0166, -0.0374],
#                       [ 0.0148,  0.0513,  0.0430,  ...,  0.0014, -0.0108,  0.0056],
#                       ...,
#                       [ 0.0059,  0.0090,  0.0030,  ..., -0.0065, -0.0055,  0.0135],
#                       [ 0.0227, -0.0120,  0.0002,  ...,  0.0051, -0.0015,  0.0049],
#                       [-0.0051,  0.0198, -0.0293,  ..., -0.0078, -0.0209, -0.0229]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.1.mlp.down_proj.weight',
#               tensor([[-0.0145, -0.0121, -0.0055,  ..., -0.0110, -0.0134,  0.0017],
#                       [ 0.0017, -0.0018,  0.0161,  ...,  0.0150, -0.0192, -0.0077],
#                       [ 0.0096, -0.0024, -0.0148,  ...,  0.0138,  0.0064,  0.0052],
#                       ...,
#                       [-0.0105,  0.0031,  0.0012,  ...,  0.0008,  0.0219,  0.0146],
#                       [-0.0181,  0.0109,  0.0403,  ..., -0.0085,  0.0076, -0.0003],
#                       [-0.0222, -0.0069, -0.0076,  ..., -0.0161, -0.0104,  0.0092]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.1.input_layernorm.weight',
#               tensor([0.1240, 0.1016, 0.2480,  ..., 0.3125, 0.1094, 0.1030],
#                      dtype=torch.bfloat16)),
#              ('model.layers.1.post_attention_layernorm.weight',
#               tensor([0.1797, 0.1758, 0.0962,  ..., 0.1084, 0.1758, 0.1807],
#                      dtype=torch.bfloat16)),
#              ('model.layers.2.self_attn.q_proj.weight',
#               tensor([[-0.0176,  0.0222, -0.0034,  ...,  0.0302,  0.0231, -0.0022],
#                       [-0.0388, -0.0209, -0.0135,  ...,  0.0039,  0.0168,  0.0129],
#                       [ 0.0330, -0.0347, -0.0124,  ...,  0.0364, -0.0084, -0.0086],
#                       ...,
#                       [ 0.0063,  0.0152, -0.0061,  ...,  0.0103, -0.0151,  0.0186],
#                       [-0.0417, -0.0371, -0.0015,  ..., -0.0083, -0.0107, -0.0114],
#                       [ 0.0437,  0.0356, -0.0040,  ...,  0.0029, -0.0222, -0.0063]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.2.self_attn.k_proj.weight',
#               tensor([[ 0.0288, -0.0092,  0.0145,  ...,  0.0400,  0.0312,  0.0093],
#                       [ 0.0513,  0.0237,  0.0513,  ..., -0.0322,  0.0101,  0.0047],
#                       [-0.0004, -0.0031, -0.0206,  ...,  0.0535,  0.0031, -0.0276],
#                       ...,
#                       [-0.0525, -0.0079, -0.0410,  ...,  0.0133,  0.0161, -0.0413],
#                       [ 0.0222,  0.0251, -0.0371,  ...,  0.0156,  0.0192,  0.0457],
#                       [ 0.0064, -0.0203,  0.0006,  ...,  0.0173, -0.0327,  0.0186]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.2.self_attn.v_proj.weight',
#               tensor([[ 0.0029, -0.0104,  0.0058,  ...,  0.0021,  0.0031,  0.0149],
#                       [ 0.0029, -0.0008,  0.0071,  ...,  0.0050,  0.0134, -0.0080],
#                       [-0.0101, -0.0089,  0.0005,  ..., -0.0098,  0.0101, -0.0023],
#                       ...,
#                       [ 0.0087,  0.0125,  0.0035,  ..., -0.0137, -0.0352,  0.0006],
#                       [ 0.0315,  0.0050, -0.0079,  ..., -0.0086, -0.0108, -0.0282],
#                       [ 0.0049,  0.0039,  0.0046,  ...,  0.0018, -0.0157,  0.0068]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.2.self_attn.o_proj.weight',
#               tensor([[ 0.0125, -0.0018,  0.0099,  ..., -0.0269,  0.0028,  0.0075],
#                       [-0.0022, -0.0190, -0.0115,  ..., -0.0089, -0.0023, -0.0017],
#                       [-0.0106, -0.0087, -0.0076,  ..., -0.0051, -0.0017,  0.0092],
#                       ...,
#                       [-0.0052,  0.0239,  0.0096,  ...,  0.0231, -0.0085, -0.0011],
#                       [-0.0265, -0.0132, -0.0075,  ...,  0.0070, -0.0049,  0.0126],
#                       [-0.0021,  0.0150,  0.0127,  ..., -0.0029,  0.0028,  0.0054]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.2.mlp.gate_proj.weight',
#               tensor([[ 0.0042, -0.0239,  0.0019,  ..., -0.0060,  0.0072,  0.0250],
#                       [ 0.0060, -0.0017, -0.0098,  ..., -0.0229, -0.0085,  0.0044],
#                       [-0.0143,  0.0104,  0.0049,  ..., -0.0129, -0.0041, -0.0168],
#                       ...,
#                       [-0.0091,  0.0095,  0.0035,  ...,  0.0157, -0.0159,  0.0267],
#                       [-0.0123, -0.0099, -0.0125,  ..., -0.0156, -0.0178, -0.0197],
#                       [ 0.0039,  0.0154,  0.0200,  ...,  0.0096,  0.0164, -0.0302]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.2.mlp.up_proj.weight',
#               tensor([[-0.0059,  0.0276, -0.0024,  ..., -0.0035,  0.0189, -0.0258],
#                       [ 0.0092, -0.0159, -0.0043,  ..., -0.0090,  0.0133,  0.0181],
#                       [ 0.0148,  0.0186,  0.0469,  ..., -0.0273,  0.0096, -0.0231],
#                       ...,
#                       [ 0.0008, -0.0012,  0.0234,  ...,  0.0173, -0.0167, -0.0036],
#                       [ 0.0233,  0.0222,  0.0037,  ...,  0.0149,  0.0135, -0.0073],
#                       [-0.0317,  0.0269, -0.0085,  ..., -0.0080,  0.0075, -0.0123]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.2.mlp.down_proj.weight',
#               tensor([[ 0.0304, -0.0134,  0.0104,  ...,  0.0039,  0.0092, -0.0500],
#                       [ 0.0005, -0.0175, -0.0064,  ...,  0.0043, -0.0223, -0.0138],
#                       [ 0.0047, -0.0092, -0.0079,  ...,  0.0103, -0.0198, -0.0212],
#                       ...,
#                       [-0.0090,  0.0011, -0.0315,  ...,  0.0216, -0.0297,  0.0276],
#                       [ 0.0447,  0.0107, -0.0165,  ..., -0.0010,  0.0154,  0.0088],
#                       [-0.0205, -0.0070, -0.0145,  ..., -0.0078, -0.0020, -0.0120]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.2.input_layernorm.weight',
#               tensor([0.3086, 0.3047, 0.5039,  ..., 0.6719, 0.2871, 0.2871],
#                      dtype=torch.bfloat16)),
#              ('model.layers.2.post_attention_layernorm.weight',
#               tensor([0.2119, 0.2158, 0.1226,  ..., 0.1387, 0.2139, 0.2207],
#                      dtype=torch.bfloat16)),
#              ('model.layers.3.self_attn.q_proj.weight',
#               tensor([[-0.0037, -0.0045,  0.0187,  ...,  0.0081, -0.0062,  0.0095],
#                       [ 0.0119, -0.0024,  0.0014,  ...,  0.0034, -0.0156,  0.0089],
#                       [ 0.0048, -0.0034,  0.0071,  ...,  0.0019, -0.0154,  0.0125],
#                       ...,
#                       [-0.0069,  0.0258,  0.0396,  ...,  0.0327,  0.0245, -0.0042],
#                       [-0.0254, -0.0271,  0.0138,  ...,  0.0150,  0.0243,  0.0199],
#                       [-0.0015, -0.0008,  0.0107,  ..., -0.0630,  0.0097, -0.0220]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.3.self_attn.k_proj.weight',
#               tensor([[-0.0198,  0.0098, -0.0064,  ...,  0.0172,  0.0111,  0.0128],
#                       [-0.0015, -0.0449, -0.0349,  ...,  0.0098, -0.0106,  0.0193],
#                       [-0.0337,  0.0128,  0.0193,  ...,  0.0056,  0.0098, -0.0134],
#                       ...,
#                       [ 0.0149, -0.0022,  0.0281,  ...,  0.0178,  0.0466, -0.0557],
#                       [-0.0576,  0.0381,  0.0051,  ..., -0.0454, -0.0203, -0.0850],
#                       [ 0.0051, -0.0002,  0.0186,  ..., -0.0449,  0.0288,  0.0205]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.3.self_attn.v_proj.weight',
#               tensor([[ 5.9891e-04, -1.6785e-03, -1.1683e-05,  ..., -2.5482e-03,
#                        -1.2695e-02, -4.3106e-04],
#                       [-1.3428e-02,  1.5747e-02,  8.6670e-03,  ...,  6.1646e-03,
#                        -1.7822e-02,  9.8877e-03],
#                       [ 2.1973e-02,  7.4463e-03, -2.8229e-03,  ..., -8.7280e-03,
#                        -9.5825e-03,  5.8594e-03],
#                       ...,
#                       [ 1.0193e-02,  9.8877e-03, -7.7438e-04,  ..., -6.1340e-03,
#                         6.3705e-04,  5.5847e-03],
#                       [ 2.6855e-02, -8.4839e-03,  1.8188e-02,  ..., -9.9487e-03,
#                         1.3123e-02,  1.7822e-02],
#                       [-1.2756e-02,  3.2349e-03, -4.3030e-03,  ...,  2.3193e-03,
#                        -2.5879e-02, -1.2878e-02]], dtype=torch.bfloat16)),
#              ('model.layers.3.self_attn.o_proj.weight',
#               tensor([[ 0.0081, -0.0028,  0.0069,  ...,  0.0114, -0.0005,  0.0076],
#                       [ 0.0103, -0.0003, -0.0093,  ..., -0.0140, -0.0415, -0.0018],
#                       [-0.0064,  0.0006,  0.0010,  ..., -0.0047,  0.0103, -0.0067],
#                       ...,
#                       [-0.0103, -0.0210, -0.0195,  ..., -0.0322, -0.0026,  0.0243],
#                       [ 0.0079, -0.0003, -0.0140,  ...,  0.0099,  0.0126, -0.0139],
#                       [-0.0090,  0.0201,  0.0277,  ..., -0.0054,  0.0143, -0.0088]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.3.mlp.gate_proj.weight',
#               tensor([[ 0.0060, -0.0054, -0.0063,  ..., -0.0122, -0.0048, -0.0286],
#                       [ 0.0356, -0.0176,  0.0471,  ..., -0.0236, -0.0137,  0.0014],
#                       [-0.0018, -0.0199,  0.0005,  ...,  0.0186, -0.0082,  0.0171],
#                       ...,
#                       [ 0.0452, -0.0312,  0.0138,  ...,  0.0028,  0.0069,  0.0060],
#                       [ 0.0109,  0.0041, -0.0020,  ...,  0.0012,  0.0205, -0.0030],
#                       [ 0.0026, -0.0074,  0.0066,  ...,  0.0063,  0.0108, -0.0022]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.3.mlp.up_proj.weight',
#               tensor([[ 0.0084,  0.0074,  0.0014,  ...,  0.0037, -0.0159, -0.0156],
#                       [ 0.0118, -0.0064, -0.0070,  ..., -0.0126, -0.0270,  0.0231],
#                       [-0.0102, -0.0139, -0.0038,  ...,  0.0337, -0.0496, -0.0016],
#                       ...,
#                       [-0.0288, -0.0087, -0.0147,  ...,  0.0010, -0.0322, -0.0016],
#                       [-0.0212, -0.0039,  0.0024,  ..., -0.0152,  0.0244,  0.0042],
#                       [ 0.0198,  0.0189,  0.0391,  ..., -0.0205, -0.0193,  0.0017]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.3.mlp.down_proj.weight',
#               tensor([[ 2.5879e-02, -1.8082e-03,  2.1240e-02,  ...,  2.0386e-02,
#                         2.6978e-02, -2.5146e-02],
#                       [ 7.7248e-05, -1.9531e-02,  2.4536e-02,  ...,  6.8665e-05,
#                        -1.6357e-02,  3.2227e-02],
#                       [-6.6528e-03,  6.6833e-03,  8.4839e-03,  ..., -5.9509e-03,
#                        -7.0496e-03,  1.2390e-02],
#                       ...,
#                       [ 7.3242e-03, -5.4321e-03,  1.6602e-02,  ...,  8.6060e-03,
#                        -1.7212e-02, -1.3123e-02],
#                       [-1.0376e-02, -2.5269e-02, -2.5635e-02,  ...,  7.1106e-03,
#                         3.8300e-03,  7.4768e-03],
#                       [ 1.4526e-02,  1.3794e-02,  1.0071e-02,  ..., -2.7100e-02,
#                         2.0508e-02, -5.4321e-03]], dtype=torch.bfloat16)),
#              ('model.layers.3.input_layernorm.weight',
#               tensor([0.3477, 0.3574, 0.3477,  ..., 0.4590, 0.3379, 0.3203],
#                      dtype=torch.bfloat16)),
#              ('model.layers.3.post_attention_layernorm.weight',
#               tensor([0.2344, 0.2305, 0.1484,  ..., 0.1504, 0.2383, 0.2402],
#                      dtype=torch.bfloat16)),
#              ('model.layers.4.self_attn.q_proj.weight',
#               tensor([[ 0.0122, -0.0339, -0.0161,  ..., -0.0041,  0.0012,  0.0113],
#                       [-0.0096,  0.0059,  0.0052,  ...,  0.0006,  0.0039, -0.0107],
#                       [ 0.0151,  0.0025, -0.0037,  ..., -0.0066,  0.0214, -0.0214],
#                       ...,
#                       [-0.0026,  0.0049,  0.0186,  ...,  0.0063,  0.0074, -0.0145],
#                       [ 0.0381,  0.0159, -0.0166,  ..., -0.0289, -0.0101,  0.0062],
#                       [-0.0004, -0.0095,  0.0217,  ...,  0.0054, -0.0366,  0.0554]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.4.self_attn.k_proj.weight',
#               tensor([[ 0.0317, -0.0298,  0.0147,  ...,  0.0381, -0.0042, -0.0034],
#                       [ 0.0103, -0.0118, -0.0447,  ..., -0.0212, -0.0116, -0.0028],
#                       [-0.0039, -0.0242,  0.0173,  ...,  0.0146, -0.0239,  0.0210],
#                       ...,
#                       [ 0.0864,  0.0332,  0.0762,  ..., -0.1006, -0.0288, -0.0645],
#                       [ 0.0088, -0.0542, -0.0303,  ...,  0.0596,  0.0065,  0.0459],
#                       [ 0.0150, -0.0063,  0.0164,  ..., -0.0128,  0.0107, -0.0061]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.4.self_attn.v_proj.weight',
#               tensor([[-1.4771e-02, -2.0508e-02,  2.8687e-03,  ...,  1.2939e-02,
#                         1.0986e-02, -1.0864e-02],
#                       [ 9.7046e-03, -1.8066e-02, -3.9482e-04,  ...,  9.8877e-03,
#                         2.4414e-02, -5.9814e-03],
#                       [ 1.7700e-02, -7.2937e-03,  3.2501e-03,  ...,  1.5106e-03,
#                        -5.6763e-03, -9.4604e-03],
#                       ...,
#                       [ 1.0193e-02,  2.4658e-02, -4.1809e-03,  ...,  1.2994e-05,
#                        -2.5635e-03, -1.0803e-02],
#                       [-1.7822e-02,  4.3945e-03, -1.8997e-03,  ..., -1.8311e-03,
#                         1.7166e-03,  3.6621e-02],
#                       [ 4.5967e-04, -6.8970e-03,  3.2187e-05,  ...,  3.7766e-04,
#                         2.0264e-02, -6.1646e-03]], dtype=torch.bfloat16)),
#              ('model.layers.4.self_attn.o_proj.weight',
#               tensor([[ 5.2490e-03, -1.3306e-02, -3.6955e-05,  ...,  5.5237e-03,
#                        -1.0132e-02,  4.6387e-03],
#                       [ 1.6602e-02, -3.1128e-02, -4.1504e-03,  ...,  7.7820e-03,
#                         2.6093e-03, -2.2095e-02],
#                       [ 3.2501e-03,  8.0566e-03,  1.4282e-02,  ..., -1.1826e-03,
#                        -9.1553e-03,  1.2573e-02],
#                       ...,
#                       [-3.6621e-03,  6.2561e-04, -8.4839e-03,  ...,  1.7578e-02,
#                        -1.2451e-02,  1.1368e-03],
#                       [ 2.1729e-02,  1.3306e-02,  2.6001e-02,  ...,  1.1108e-02,
#                         3.3417e-03,  1.9897e-02],
#                       [ 1.5869e-02,  2.7771e-03,  1.3611e-02,  ..., -5.8289e-03,
#                         1.9531e-02,  6.4087e-03]], dtype=torch.bfloat16)),
#              ('model.layers.4.mlp.gate_proj.weight',
#               tensor([[ 0.0018,  0.0095,  0.0057,  ..., -0.0047,  0.0060, -0.0160],
#                       [-0.0063,  0.0085,  0.0034,  ...,  0.0159,  0.0008, -0.0013],
#                       [ 0.0097,  0.0010, -0.0052,  ..., -0.0055, -0.0295, -0.0045],
#                       ...,
#                       [ 0.0082,  0.0332,  0.0361,  ..., -0.0057,  0.0488,  0.0022],
#                       [-0.0053,  0.0204,  0.0117,  ...,  0.0154, -0.0233, -0.0059],
#                       [ 0.0118,  0.0410, -0.0148,  ...,  0.0014, -0.0093, -0.0352]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.4.mlp.up_proj.weight',
#               tensor([[ 0.0129, -0.0098, -0.0065,  ...,  0.0029, -0.0204, -0.0007],
#                       [ 0.0206, -0.0200, -0.0104,  ...,  0.0048,  0.0173,  0.0156],
#                       [ 0.0283,  0.0089, -0.0051,  ...,  0.0189, -0.0242, -0.0183],
#                       ...,
#                       [ 0.0173,  0.0053,  0.0053,  ..., -0.0011,  0.0018,  0.0090],
#                       [-0.0057,  0.0347, -0.0089,  ...,  0.0187, -0.0101,  0.0076],
#                       [-0.0106,  0.0047,  0.0050,  ...,  0.0140, -0.0530,  0.0010]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.4.mlp.down_proj.weight',
#               tensor([[ 0.0025, -0.0066, -0.0070,  ..., -0.0134, -0.0058, -0.0173],
#                       [ 0.0145, -0.0187,  0.0162,  ..., -0.0060,  0.0226,  0.0069],
#                       [ 0.0025, -0.0032, -0.0022,  ..., -0.0171, -0.0037,  0.0040],
#                       ...,
#                       [-0.0053,  0.0064,  0.0034,  ..., -0.0010,  0.0150,  0.0229],
#                       [ 0.0182,  0.0060, -0.0148,  ..., -0.0090, -0.0029, -0.0024],
#                       [ 0.0096,  0.0090,  0.0008,  ..., -0.0138,  0.0300,  0.0206]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.4.input_layernorm.weight',
#               tensor([0.3145, 0.3203, 0.4141,  ..., 0.3906, 0.2812, 0.2695],
#                      dtype=torch.bfloat16)),
#              ('model.layers.4.post_attention_layernorm.weight',
#               tensor([0.2461, 0.2461, 0.1602,  ..., 0.1738, 0.2539, 0.2480],
#                      dtype=torch.bfloat16)),
#              ('model.layers.5.self_attn.q_proj.weight',
#               tensor([[-0.0074, -0.0121, -0.0125,  ..., -0.0075, -0.0040, -0.0007],
#                       [-0.0166,  0.0118, -0.0148,  ..., -0.0052,  0.0129, -0.0256],
#                       [-0.0142, -0.0045, -0.0222,  ...,  0.0026,  0.0036,  0.0156],
#                       ...,
#                       [ 0.0330,  0.0110, -0.0098,  ..., -0.0238, -0.0649, -0.0137],
#                       [-0.0237,  0.0131, -0.0195,  ..., -0.0099, -0.0269,  0.0486],
#                       [ 0.0114, -0.0032, -0.0100,  ..., -0.0009,  0.0464, -0.0212]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.5.self_attn.k_proj.weight',
#               tensor([[ 1.1230e-02,  2.7100e-02, -8.2397e-03,  ...,  9.5844e-05,
#                         5.8594e-03,  2.2461e-02],
#                       [ 3.5400e-02,  4.8340e-02,  4.0283e-02,  ..., -2.8931e-02,
#                         2.9297e-02,  2.3560e-02],
#                       [ 5.3101e-03, -7.4463e-03,  2.9297e-02,  ...,  5.7068e-03,
#                         1.5503e-02,  4.1809e-03],
#                       ...,
#                       [-1.9653e-02, -6.4941e-02,  1.4221e-02,  ...,  5.8105e-02,
#                         4.1260e-02, -4.4678e-02],
#                       [-2.3346e-03,  1.8555e-02,  1.8921e-03,  ..., -1.9043e-02,
#                        -2.3193e-02,  5.7617e-02],
#                       [ 2.5757e-02,  1.8433e-02, -3.7842e-02,  ...,  6.7749e-03,
#                        -2.7100e-02,  1.3885e-03]], dtype=torch.bfloat16)),
#              ('model.layers.5.self_attn.v_proj.weight',
#               tensor([[-0.0181,  0.0186, -0.0025,  ...,  0.0020,  0.0110,  0.0082],
#                       [ 0.0198,  0.0032, -0.0038,  ...,  0.0010,  0.0061, -0.0121],
#                       [ 0.0021, -0.0156, -0.0009,  ..., -0.0029,  0.0273, -0.0113],
#                       ...,
#                       [-0.0197,  0.0029,  0.0003,  ...,  0.0043,  0.0148,  0.0055],
#                       [-0.0082,  0.0280, -0.0043,  ...,  0.0035,  0.0053,  0.0005],
#                       [ 0.0002, -0.0017, -0.0018,  ..., -0.0019, -0.0009,  0.0039]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.5.self_attn.o_proj.weight',
#               tensor([[-0.0100, -0.0381,  0.0110,  ..., -0.0288, -0.0020,  0.0125],
#                       [-0.0039,  0.0107, -0.0135,  ..., -0.0061,  0.0295,  0.0126],
#                       [ 0.0012, -0.0038, -0.0015,  ..., -0.0021,  0.0045, -0.0078],
#                       ...,
#                       [ 0.0005, -0.0107,  0.0308,  ...,  0.0206, -0.0068, -0.0126],
#                       [-0.0050, -0.0111, -0.0156,  ..., -0.0164, -0.0317,  0.0153],
#                       [ 0.0121,  0.0092, -0.0036,  ...,  0.0142,  0.0220, -0.0121]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.5.mlp.gate_proj.weight',
#               tensor([[-0.0038,  0.0040, -0.0006,  ...,  0.0156,  0.0065,  0.0065],
#                       [ 0.0002,  0.0096,  0.0008,  ...,  0.0145,  0.0217, -0.0337],
#                       [-0.0074,  0.0386,  0.0249,  ...,  0.0300, -0.0053, -0.0118],
#                       ...,
#                       [-0.0176, -0.0081, -0.0093,  ..., -0.0109, -0.0339,  0.0181],
#                       [-0.0347, -0.0247,  0.0376,  ...,  0.0140, -0.0106,  0.0254],
#                       [ 0.0288, -0.0356, -0.0159,  ...,  0.0359,  0.0254, -0.0131]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.5.mlp.up_proj.weight',
#               tensor([[ 0.0239,  0.0188, -0.0096,  ..., -0.0015,  0.0002, -0.0143],
#                       [ 0.0070,  0.0107,  0.0104,  ...,  0.0234, -0.0261,  0.0171],
#                       [-0.0083, -0.0139, -0.0197,  ...,  0.0151,  0.0214,  0.0322],
#                       ...,
#                       [-0.0427, -0.0152,  0.0099,  ...,  0.0089,  0.0576, -0.0036],
#                       [-0.0081,  0.0135, -0.0154,  ...,  0.0134, -0.0123,  0.0040],
#                       [-0.0118, -0.0159,  0.0136,  ..., -0.0035,  0.0210, -0.0151]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.5.mlp.down_proj.weight',
#               tensor([[ 0.0194,  0.0042, -0.0018,  ..., -0.0393, -0.0131, -0.0013],
#                       [ 0.0054, -0.0127,  0.0007,  ..., -0.0116, -0.0242, -0.0054],
#                       [-0.0302,  0.0015, -0.0195,  ...,  0.0060,  0.0053, -0.0018],
#                       ...,
#                       [ 0.0146,  0.0374,  0.0012,  ...,  0.0209, -0.0183,  0.0031],
#                       [ 0.0176, -0.0253,  0.0172,  ...,  0.0562, -0.0259,  0.0155],
#                       [-0.0010,  0.0181,  0.0272,  ..., -0.0199,  0.0310, -0.0101]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.5.input_layernorm.weight',
#               tensor([0.3535, 0.3711, 0.4297,  ..., 0.5586, 0.3027, 0.2910],
#                      dtype=torch.bfloat16)),
#              ('model.layers.5.post_attention_layernorm.weight',
#               tensor([0.2559, 0.2578, 0.1465,  ..., 0.1934, 0.2695, 0.2695],
#                      dtype=torch.bfloat16)),
#              ('model.layers.6.self_attn.q_proj.weight',
#               tensor([[-0.0024,  0.0425,  0.0197,  ...,  0.0030,  0.0264, -0.0188],
#                       [-0.0178, -0.0286, -0.0058,  ...,  0.0045, -0.0371,  0.0060],
#                       [ 0.0110, -0.0194,  0.0007,  ..., -0.0610,  0.0118, -0.0039],
#                       ...,
#                       [-0.0021,  0.0111, -0.0118,  ..., -0.0097, -0.0054, -0.0295],
#                       [-0.0139,  0.0027,  0.0051,  ..., -0.0127,  0.0171,  0.0199],
#                       [-0.0019,  0.0046, -0.0166,  ...,  0.0036, -0.0147, -0.0059]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.6.self_attn.k_proj.weight',
#               tensor([[-0.0292, -0.0281,  0.0215,  ..., -0.0016, -0.0123,  0.0322],
#                       [ 0.0420, -0.0386, -0.0100,  ...,  0.0004,  0.0093,  0.0037],
#                       [ 0.0198,  0.0503,  0.0098,  ..., -0.0067,  0.0114,  0.0062],
#                       ...,
#                       [ 0.0889,  0.0396, -0.0762,  ..., -0.0322,  0.0088, -0.0157],
#                       [-0.0247,  0.0035, -0.1079,  ..., -0.0034, -0.0228, -0.0171],
#                       [ 0.0464,  0.0033,  0.0508,  ...,  0.0114, -0.0518,  0.0140]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.6.self_attn.v_proj.weight',
#               tensor([[-0.0094,  0.0073,  0.0087,  ...,  0.0042, -0.0334,  0.0049],
#                       [ 0.0125, -0.0210, -0.0148,  ...,  0.0066, -0.0140,  0.0234],
#                       [ 0.0042,  0.0195, -0.0033,  ...,  0.0022,  0.0172, -0.0106],
#                       ...,
#                       [-0.0099,  0.0081,  0.0041,  ...,  0.0092, -0.0181,  0.0171],
#                       [-0.0247,  0.0112, -0.0111,  ..., -0.0049,  0.0112,  0.0117],
#                       [-0.0173,  0.0003, -0.0101,  ..., -0.0026, -0.0039,  0.0082]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.6.self_attn.o_proj.weight',
#               tensor([[ 0.0082,  0.0148, -0.0137,  ..., -0.0256,  0.0034, -0.0310],
#                       [ 0.0200, -0.0117,  0.0238,  ...,  0.0101,  0.0023,  0.0008],
#                       [-0.0071,  0.0036, -0.0059,  ..., -0.0104, -0.0197,  0.0022],
#                       ...,
#                       [-0.0013, -0.0087,  0.0128,  ...,  0.0088, -0.0148,  0.0161],
#                       [ 0.0205,  0.0031,  0.0142,  ..., -0.0200, -0.0137, -0.0161],
#                       [ 0.0152,  0.0137,  0.0076,  ...,  0.0259,  0.0041, -0.0082]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.6.mlp.gate_proj.weight',
#               tensor([[-3.4027e-03,  1.6357e-02,  1.2573e-02,  ..., -1.2939e-02,
#                         7.7515e-03,  1.0498e-02],
#                       [ 7.6599e-03, -8.8501e-03,  1.2512e-02,  ..., -3.4180e-02,
#                         2.2583e-03, -2.2217e-02],
#                       [-1.1475e-02, -8.4229e-03, -1.3977e-02,  ...,  9.5215e-03,
#                         3.2959e-03, -2.6733e-02],
#                       ...,
#                       [-9.8267e-03,  6.8054e-03,  2.1240e-02,  ...,  2.0752e-03,
#                        -4.6387e-03, -9.9487e-03],
#                       [-1.0620e-02, -3.3447e-02, -2.6001e-02,  ...,  5.7983e-03,
#                        -2.9175e-02, -4.2915e-05],
#                       [-3.2715e-02, -1.1597e-02,  3.2806e-03,  ..., -1.2939e-02,
#                         8.7891e-03, -2.9053e-02]], dtype=torch.bfloat16)),
#              ('model.layers.6.mlp.up_proj.weight',
#               tensor([[ 0.0031,  0.0221,  0.0066,  ...,  0.0087,  0.0145,  0.0052],
#                       [ 0.0176,  0.0193, -0.0106,  ..., -0.0039, -0.0131,  0.0016],
#                       [ 0.0018, -0.0042, -0.0110,  ...,  0.0200, -0.0293, -0.0210],
#                       ...,
#                       [-0.0019,  0.0074, -0.0041,  ...,  0.0087, -0.0198, -0.0036],
#                       [ 0.0126, -0.0074, -0.0178,  ...,  0.0237,  0.0076,  0.0072],
#                       [-0.0112,  0.0007,  0.0085,  ..., -0.0143,  0.0058,  0.0078]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.6.mlp.down_proj.weight',
#               tensor([[-1.6724e-02,  8.1539e-05,  2.3560e-02,  ..., -9.2773e-03,
#                         5.2185e-03,  1.3367e-02],
#                       [ 1.1658e-02,  1.3046e-03,  1.0864e-02,  ..., -1.3977e-02,
#                        -6.3477e-02,  1.7166e-04],
#                       [ 1.1108e-02,  1.0376e-02, -1.1597e-03,  ...,  1.9379e-03,
#                         5.4932e-04,  1.1368e-03],
#                       ...,
#                       [ 5.3101e-03,  1.1978e-03, -9.6436e-03,  ..., -2.4567e-03,
#                         3.1982e-02, -1.4526e-02],
#                       [ 7.1106e-03, -1.9264e-04, -1.3184e-02,  ...,  1.1475e-02,
#                        -3.1128e-03,  1.0498e-02],
#                       [ 1.5259e-02,  2.1240e-02, -1.0620e-02,  ...,  6.5613e-03,
#                        -1.1719e-02,  1.4038e-02]], dtype=torch.bfloat16)),
#              ('model.layers.6.input_layernorm.weight',
#               tensor([0.3535, 0.3867, 0.3223,  ..., 0.4297, 0.2969, 0.2891],
#                      dtype=torch.bfloat16)),
#              ('model.layers.6.post_attention_layernorm.weight',
#               tensor([0.2598, 0.2695, 0.1494,  ..., 0.2168, 0.2734, 0.2617],
#                      dtype=torch.bfloat16)),
#              ('model.layers.7.self_attn.q_proj.weight',
#               tensor([[ 0.0286,  0.0012,  0.0054,  ..., -0.0284, -0.0222,  0.0016],
#                       [ 0.0025,  0.0032,  0.0016,  ..., -0.0214, -0.0081, -0.0117],
#                       [-0.0030, -0.0111, -0.0464,  ..., -0.0165, -0.0143,  0.0144],
#                       ...,
#                       [-0.0166,  0.0085, -0.0079,  ...,  0.0304, -0.0062,  0.0413],
#                       [-0.0217, -0.0223,  0.0312,  ..., -0.0183, -0.0084,  0.0212],
#                       [-0.0469, -0.0104,  0.0179,  ...,  0.0107, -0.0044,  0.0312]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.7.self_attn.k_proj.weight',
#               tensor([[-0.0156,  0.0625, -0.0276,  ..., -0.0093, -0.0327,  0.0002],
#                       [-0.0042,  0.0183, -0.0457,  ..., -0.0270, -0.0361,  0.0044],
#                       [-0.0223,  0.0075, -0.0288,  ..., -0.0121, -0.0225, -0.0134],
#                       ...,
#                       [ 0.0913,  0.0317,  0.0195,  ...,  0.0006,  0.0276, -0.0259],
#                       [-0.0281, -0.0376, -0.0376,  ...,  0.0195,  0.0522, -0.0183],
#                       [ 0.0073,  0.0703,  0.0186,  ...,  0.0040, -0.0005,  0.0300]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.7.self_attn.v_proj.weight',
#               tensor([[ 0.0081, -0.0009,  0.0024,  ..., -0.0212,  0.0116, -0.0045],
#                       [ 0.0004,  0.0101, -0.0019,  ..., -0.0060, -0.0036,  0.0101],
#                       [-0.0095, -0.0022,  0.0256,  ...,  0.0030, -0.0099, -0.0011],
#                       ...,
#                       [-0.0094,  0.0074,  0.0134,  ...,  0.0078, -0.0016,  0.0016],
#                       [ 0.0149, -0.0101, -0.0073,  ..., -0.0116, -0.0093,  0.0371],
#                       [-0.0248,  0.0007, -0.0007,  ...,  0.0089,  0.0165,  0.0027]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.7.self_attn.o_proj.weight',
#               tensor([[ 0.0145,  0.0293,  0.0162,  ..., -0.0074, -0.0231,  0.0005],
#                       [ 0.0061, -0.0250,  0.0033,  ...,  0.0048, -0.0071, -0.0036],
#                       [ 0.0094,  0.0037, -0.0061,  ..., -0.0037, -0.0013, -0.0003],
#                       ...,
#                       [ 0.0022, -0.0112, -0.0122,  ..., -0.0092,  0.0001, -0.0042],
#                       [ 0.0148,  0.0079, -0.0045,  ...,  0.0220, -0.0026,  0.0076],
#                       [-0.0073, -0.0068,  0.0079,  ..., -0.0004, -0.0081,  0.0043]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.7.mlp.gate_proj.weight',
#               tensor([[-0.0048, -0.0144, -0.0051,  ...,  0.0041,  0.0188,  0.0048],
#                       [-0.0190, -0.0325,  0.0156,  ..., -0.0076,  0.0014,  0.0312],
#                       [ 0.0493,  0.0752,  0.0220,  ...,  0.0162, -0.0066, -0.0312],
#                       ...,
#                       [-0.0183,  0.0327,  0.0023,  ..., -0.0047, -0.0061, -0.0023],
#                       [ 0.0444, -0.0186, -0.0125,  ..., -0.0036, -0.0187,  0.0210],
#                       [ 0.0033, -0.0050,  0.0104,  ...,  0.0084, -0.0046,  0.0082]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.7.mlp.up_proj.weight',
#               tensor([[ 0.0273, -0.0075, -0.0149,  ..., -0.0074,  0.0214,  0.0012],
#                       [ 0.0088,  0.0204, -0.0048,  ...,  0.0101,  0.0265,  0.0361],
#                       [ 0.0454,  0.0106,  0.0055,  ..., -0.0170,  0.0253,  0.0020],
#                       ...,
#                       [ 0.0175,  0.0153, -0.0019,  ...,  0.0293, -0.0059, -0.0089],
#                       [-0.0264, -0.0085,  0.0332,  ..., -0.0077, -0.0032,  0.0256],
#                       [-0.0347,  0.0178, -0.0070,  ...,  0.0177, -0.0021, -0.0059]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.7.mlp.down_proj.weight',
#               tensor([[ 1.0925e-02,  2.8198e-02,  3.0762e-02,  ..., -1.3184e-02,
#                        -8.3008e-03, -1.7334e-02],
#                       [ 1.4282e-02,  1.2573e-02, -1.4038e-02,  ...,  2.1362e-02,
#                        -1.3199e-03,  1.3123e-02],
#                       [ 8.3008e-03,  2.2984e-04, -4.0894e-03,  ...,  7.4158e-03,
#                         1.0620e-02,  9.7046e-03],
#                       ...,
#                       [-5.4626e-03, -6.9809e-04, -1.1841e-02,  ...,  2.1118e-02,
#                        -2.2705e-02,  2.5146e-02],
#                       [-2.6611e-02,  1.1368e-03,  1.0376e-03,  ..., -5.4932e-03,
#                         3.3203e-02, -1.5259e-05],
#                       [ 8.3923e-04,  3.0029e-02, -3.2349e-03,  ...,  1.3733e-03,
#                        -3.3264e-03,  2.8809e-02]], dtype=torch.bfloat16)),
#              ('model.layers.7.input_layernorm.weight',
#               tensor([0.3574, 0.4160, 0.2480,  ..., 0.3711, 0.3027, 0.2891],
#                      dtype=torch.bfloat16)),
#              ('model.layers.7.post_attention_layernorm.weight',
#               tensor([0.2715, 0.2656, 0.1475,  ..., 0.2227, 0.2695, 0.2617],
#                      dtype=torch.bfloat16)),
#              ('model.layers.8.self_attn.q_proj.weight',
#               tensor([[-0.0227, -0.0167,  0.0165,  ...,  0.0178, -0.0060,  0.0008],
#                       [-0.0064, -0.0152,  0.0142,  ...,  0.0137,  0.0102,  0.0062],
#                       [-0.0035, -0.0161, -0.0005,  ...,  0.0006,  0.0056, -0.0171],
#                       ...,
#                       [-0.0065,  0.0115, -0.0154,  ..., -0.0159, -0.0123,  0.0171],
#                       [-0.0063, -0.0330, -0.0070,  ...,  0.0053, -0.0305,  0.0015],
#                       [-0.0016, -0.0208, -0.0104,  ...,  0.0046, -0.0072,  0.0232]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.8.self_attn.k_proj.weight',
#               tensor([[-0.0087, -0.0026, -0.0187,  ..., -0.0030,  0.0072,  0.0065],
#                       [ 0.0222, -0.0014, -0.0068,  ...,  0.0193,  0.0118,  0.0189],
#                       [ 0.0023,  0.0168,  0.0033,  ..., -0.0027,  0.0019, -0.0119],
#                       ...,
#                       [-0.0408,  0.0359,  0.0069,  ...,  0.0127,  0.0265,  0.0145],
#                       [-0.0048,  0.0116, -0.0247,  ...,  0.0103,  0.0393,  0.0064],
#                       [-0.0175, -0.0060, -0.0610,  ..., -0.0376, -0.0466, -0.0315]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.8.self_attn.v_proj.weight',
#               tensor([[ 4.6997e-03, -1.1902e-03, -8.5449e-03,  ..., -8.2016e-04,
#                         2.5330e-03, -1.0193e-02],
#                       [-5.5542e-03, -3.0823e-03,  9.8877e-03,  ..., -9.9487e-03,
#                        -7.1411e-03, -2.1973e-02],
#                       [ 6.0730e-03, -1.5736e-05, -1.1673e-03,  ..., -1.2390e-02,
#                        -2.3315e-02, -9.2773e-03],
#                       ...,
#                       [ 1.3550e-02,  4.4556e-03, -1.6022e-03,  ...,  5.3024e-04,
#                         8.2397e-03,  1.1414e-02],
#                       [ 3.4180e-03,  6.1340e-03,  6.4850e-05,  ...,  3.0975e-03,
#                        -5.1575e-03, -6.4697e-03],
#                       [ 2.0630e-02, -1.2634e-02, -1.0376e-02,  ..., -1.1520e-03,
#                        -9.3460e-04, -6.4697e-03]], dtype=torch.bfloat16)),
#              ('model.layers.8.self_attn.o_proj.weight',
#               tensor([[ 0.0119,  0.0140,  0.0074,  ..., -0.0117, -0.0132, -0.0232],
#                       [-0.0080, -0.0110, -0.0211,  ...,  0.0194, -0.0087, -0.0014],
#                       [ 0.0012, -0.0015,  0.0034,  ...,  0.0060,  0.0008,  0.0038],
#                       ...,
#                       [ 0.0033, -0.0113,  0.0055,  ...,  0.0151,  0.0070, -0.0004],
#                       [-0.0204,  0.0017,  0.0145,  ..., -0.0008,  0.0264,  0.0184],
#                       [ 0.0096, -0.0073, -0.0009,  ..., -0.0124,  0.0297, -0.0034]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.8.mlp.gate_proj.weight',
#               tensor([[ 0.0037,  0.0140, -0.0287,  ...,  0.0027, -0.0229,  0.0068],
#                       [-0.0030, -0.0039, -0.0018,  ...,  0.0015,  0.0039,  0.0018],
#                       [-0.0249,  0.0071,  0.0112,  ..., -0.0103, -0.0123, -0.0124],
#                       ...,
#                       [ 0.0225, -0.0111,  0.0034,  ...,  0.0226, -0.0106,  0.0144],
#                       [-0.0193, -0.0106,  0.0023,  ...,  0.0315, -0.0151, -0.0270],
#                       [-0.0364, -0.0009, -0.0011,  ..., -0.0139,  0.0097, -0.0056]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.8.mlp.up_proj.weight',
#               tensor([[ 0.0151, -0.0168, -0.0242,  ..., -0.0234, -0.0049,  0.0120],
#                       [-0.0047, -0.0327,  0.0135,  ..., -0.0452,  0.0031, -0.0036],
#                       [ 0.0175,  0.0201,  0.0004,  ..., -0.0204, -0.0176, -0.0222],
#                       ...,
#                       [ 0.0386, -0.0036,  0.0001,  ..., -0.0339, -0.0135, -0.0057],
#                       [ 0.0031,  0.0040, -0.0009,  ..., -0.0157, -0.0287,  0.0190],
#                       [ 0.0079,  0.0251,  0.0026,  ...,  0.0259, -0.0066, -0.0034]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.8.mlp.down_proj.weight',
#               tensor([[ 0.0099,  0.0104,  0.0048,  ...,  0.0325,  0.0135, -0.0084],
#                       [-0.0096, -0.0232,  0.0118,  ..., -0.0398,  0.0013,  0.0231],
#                       [ 0.0050,  0.0036, -0.0003,  ...,  0.0127, -0.0036, -0.0019],
#                       ...,
#                       [-0.0405, -0.0311,  0.0113,  ..., -0.0115,  0.0029,  0.0063],
#                       [-0.0233,  0.0225, -0.0004,  ..., -0.0031, -0.0325, -0.0262],
#                       [-0.0060,  0.0038, -0.0206,  ..., -0.0077,  0.0060, -0.0133]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.8.input_layernorm.weight',
#               tensor([0.3984, 0.4336, 0.3086,  ..., 0.3691, 0.2988, 0.3047],
#                      dtype=torch.bfloat16)),
#              ('model.layers.8.post_attention_layernorm.weight',
#               tensor([0.2676, 0.2676, 0.1436,  ..., 0.2324, 0.2715, 0.2637],
#                      dtype=torch.bfloat16)),
#              ('model.layers.9.self_attn.q_proj.weight',
#               tensor([[-0.0021,  0.0143,  0.0092,  ...,  0.0206,  0.0144, -0.0038],
#                       [-0.0135,  0.0203,  0.0225,  ..., -0.0254, -0.0003, -0.0161],
#                       [-0.0154, -0.0041, -0.0042,  ..., -0.0155, -0.0332, -0.0072],
#                       ...,
#                       [-0.0214, -0.0011, -0.0273,  ..., -0.0415,  0.0286,  0.0104],
#                       [-0.0601,  0.1523,  0.0044,  ...,  0.0378, -0.0251,  0.0228],
#                       [ 0.0052,  0.0081, -0.0317,  ..., -0.0312, -0.0146, -0.0413]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.9.self_attn.k_proj.weight',
#               tensor([[-0.0033,  0.0027, -0.0073,  ...,  0.0036,  0.0243,  0.0195],
#                       [ 0.0204,  0.0062, -0.0374,  ...,  0.0018, -0.0031, -0.0006],
# ...
#               tensor([0.4844, 0.4844, 0.7383,  ..., 0.4805, 0.4277, 0.4531],
#                      dtype=torch.bfloat16)),
#              ('model.layers.24.post_attention_layernorm.weight',
#               tensor([0.4453, 0.4453, 0.3398,  ..., 0.4395, 0.4434, 0.4434],
#                      dtype=torch.bfloat16)),
#              ('model.layers.25.self_attn.q_proj.weight',
#               tensor([[-0.0204, -0.0039,  0.0049,  ..., -0.0072, -0.0045,  0.0029],
#                       [ 0.0046,  0.0134, -0.0128,  ..., -0.0044,  0.0014,  0.0153],
#                       [ 0.0177, -0.0260,  0.0297,  ...,  0.0182,  0.0153,  0.0081],
#                       ...,
#                       [ 0.0146, -0.0287,  0.0322,  ...,  0.0005, -0.0349, -0.0071],
#                       [-0.0095,  0.0049,  0.0025,  ...,  0.0005,  0.0193, -0.0092],
#                       [ 0.0062, -0.0198, -0.0200,  ...,  0.0317,  0.0264,  0.0537]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.25.self_attn.k_proj.weight',
#               tensor([[-0.0089,  0.0070,  0.0011,  ..., -0.0256,  0.0178,  0.0188],
#                       [ 0.0050,  0.0361,  0.0066,  ...,  0.0437,  0.0048, -0.0277],
#                       [-0.0437, -0.0112, -0.0294,  ..., -0.0176, -0.0142, -0.0703],
#                       ...,
#                       [ 0.0262, -0.0376, -0.0023,  ..., -0.0277,  0.0051, -0.0330],
#                       [ 0.0087,  0.0127,  0.0206,  ...,  0.0007,  0.0232, -0.0247],
#                       [ 0.0095,  0.0144, -0.0264,  ..., -0.0137,  0.0044, -0.0352]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.25.self_attn.v_proj.weight',
#               tensor([[ 0.0254,  0.0053,  0.0011,  ...,  0.0066, -0.0062,  0.0330],
#                       [-0.0152, -0.0103,  0.0044,  ...,  0.0386,  0.0144, -0.0175],
#                       [ 0.0045,  0.0281, -0.0076,  ...,  0.0059, -0.0535, -0.0300],
#                       ...,
#                       [-0.0047, -0.0294,  0.0040,  ...,  0.0094,  0.0086,  0.0019],
#                       [-0.0093,  0.0278, -0.0019,  ..., -0.0150, -0.0166, -0.0044],
#                       [ 0.0166,  0.0026,  0.0062,  ..., -0.0126,  0.0153, -0.0264]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.25.self_attn.o_proj.weight',
#               tensor([[-0.0288,  0.0009,  0.0126,  ...,  0.0010, -0.0017,  0.0259],
#                       [ 0.0142,  0.0244, -0.0166,  ..., -0.0209,  0.0298,  0.0054],
#                       [-0.0077,  0.0256, -0.0027,  ...,  0.0071,  0.0106,  0.0176],
#                       ...,
#                       [ 0.0194, -0.0097,  0.0208,  ...,  0.0222, -0.0233, -0.0083],
#                       [ 0.0172, -0.0063, -0.0046,  ...,  0.0101, -0.0217, -0.0114],
#                       [ 0.0127, -0.0098, -0.0024,  ...,  0.0028,  0.0041, -0.0278]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.25.mlp.gate_proj.weight',
#               tensor([[ 0.0306, -0.0562, -0.0155,  ..., -0.0454,  0.0090,  0.0601],
#                       [-0.0240,  0.0031, -0.0026,  ...,  0.0171,  0.0183, -0.0216],
#                       [-0.0064, -0.0140,  0.0045,  ..., -0.0038, -0.0303, -0.0121],
#                       ...,
#                       [ 0.0237, -0.0305,  0.0051,  ...,  0.0229, -0.0037,  0.0161],
#                       [-0.0067, -0.0137, -0.0190,  ..., -0.0156,  0.0152,  0.0080],
#                       [-0.0100, -0.0183,  0.0217,  ..., -0.0211,  0.0011,  0.0156]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.25.mlp.up_proj.weight',
#               tensor([[ 0.0118, -0.0167, -0.0014,  ...,  0.0034, -0.0088,  0.0267],
#                       [ 0.0019,  0.0096, -0.0042,  ..., -0.0093,  0.0112,  0.0361],
#                       [ 0.0020, -0.0029, -0.0116,  ...,  0.0135,  0.0254,  0.0140],
#                       ...,
#                       [ 0.0051,  0.0085, -0.0674,  ..., -0.0118,  0.0014, -0.0145],
#                       [ 0.0217, -0.0273, -0.0092,  ...,  0.0026,  0.0056, -0.0084],
#                       [ 0.0043, -0.0266,  0.0142,  ...,  0.0031,  0.0310, -0.0067]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.25.mlp.down_proj.weight',
#               tensor([[-0.0055,  0.0215,  0.0140,  ...,  0.0003, -0.0094,  0.0188],
#                       [ 0.0145,  0.0186, -0.0033,  ...,  0.0374,  0.0043,  0.0216],
#                       [ 0.0048, -0.0125, -0.0049,  ..., -0.0221, -0.0078, -0.0040],
#                       ...,
#                       [-0.0104, -0.0549, -0.0212,  ...,  0.0020, -0.0150, -0.0166],
#                       [ 0.0229, -0.0123, -0.0278,  ..., -0.0222,  0.0280,  0.0165],
#                       [-0.0275, -0.0024, -0.0126,  ...,  0.0159, -0.0157,  0.0107]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.25.input_layernorm.weight',
#               tensor([0.4980, 0.5234, 0.6133,  ..., 0.4863, 0.4512, 0.4746],
#                      dtype=torch.bfloat16)),
#              ('model.layers.25.post_attention_layernorm.weight',
#               tensor([0.4668, 0.4746, 0.3828,  ..., 0.4648, 0.4629, 0.4570],
#                      dtype=torch.bfloat16)),
#              ('model.layers.26.self_attn.q_proj.weight',
#               tensor([[-0.0073,  0.0041,  0.0178,  ..., -0.0018, -0.0103, -0.0072],
#                       [ 0.0095, -0.0393, -0.0053,  ..., -0.0181,  0.0247, -0.0034],
#                       [-0.0248, -0.0280, -0.0175,  ..., -0.0033, -0.0098,  0.0183],
#                       ...,
#                       [ 0.0077,  0.0454, -0.0255,  ..., -0.0256, -0.0201,  0.0459],
#                       [-0.0503, -0.0026, -0.0178,  ..., -0.0052, -0.0227, -0.0237],
#                       [ 0.0027, -0.0226, -0.0023,  ..., -0.0361,  0.0087, -0.0253]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.26.self_attn.k_proj.weight',
#               tensor([[ 3.4637e-03,  3.8086e-02, -2.9297e-02,  ..., -1.7090e-02,
#                        -4.6082e-03,  1.6846e-02],
#                       [ 4.9744e-03, -1.5320e-02,  2.8076e-02,  ..., -1.0498e-02,
#                        -6.8665e-03,  1.8188e-02],
#                       [ 3.8147e-03, -4.3945e-02,  6.5918e-03,  ...,  1.2878e-02,
#                        -9.7656e-04, -2.0264e-02],
#                       ...,
#                       [-6.6223e-03, -2.8076e-02,  3.5645e-02,  ...,  1.7944e-02,
#                         2.7161e-03, -1.8835e-05],
#                       [ 3.5400e-03, -8.0566e-03, -4.1992e-02,  ...,  2.4536e-02,
#                         9.0942e-03,  4.1504e-02],
#                       [ 1.2756e-02, -2.8320e-02, -2.5330e-03,  ...,  9.0332e-03,
#                        -8.8501e-03,  9.6436e-03]], dtype=torch.bfloat16)),
#              ('model.layers.26.self_attn.v_proj.weight',
#               tensor([[-0.0148, -0.0145,  0.0112,  ...,  0.0118, -0.0280, -0.0082],
#                       [ 0.0437,  0.0074,  0.0041,  ...,  0.0479, -0.0206, -0.0172],
#                       [-0.0109,  0.0168,  0.0025,  ..., -0.0009, -0.0383, -0.0226],
#                       ...,
#                       [ 0.0132,  0.0033, -0.0771,  ..., -0.0415,  0.0044, -0.0110],
#                       [-0.0085, -0.0378,  0.0510,  ...,  0.0075,  0.0140, -0.0322],
#                       [-0.0278,  0.0031,  0.0527,  ...,  0.0295,  0.0081,  0.0139]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.26.self_attn.o_proj.weight',
#               tensor([[ 0.0090, -0.0137, -0.0062,  ...,  0.0171, -0.0077, -0.0048],
#                       [-0.0037, -0.0112, -0.0017,  ..., -0.0052, -0.0101, -0.0094],
#                       [-0.0137,  0.0029, -0.0247,  ..., -0.0194, -0.0173,  0.0200],
#                       ...,
#                       [-0.0061, -0.0273, -0.0001,  ..., -0.0114,  0.0064,  0.0347],
#                       [ 0.0186,  0.0396,  0.0267,  ...,  0.0072,  0.0347,  0.0330],
#                       [ 0.0065, -0.0035,  0.0192,  ..., -0.0066, -0.0065, -0.0294]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.26.mlp.gate_proj.weight',
#               tensor([[ 0.0062,  0.0006, -0.0029,  ...,  0.0123, -0.0374, -0.0110],
#                       [-0.0121,  0.0220, -0.0178,  ..., -0.0072, -0.0114, -0.0312],
#                       [ 0.0085, -0.0522,  0.0096,  ..., -0.0072, -0.0181, -0.0117],
#                       ...,
#                       [-0.0405, -0.0039,  0.0027,  ...,  0.0060,  0.0265, -0.0024],
#                       [-0.0168,  0.0085,  0.0124,  ...,  0.0234, -0.0181, -0.0227],
#                       [-0.0129,  0.0035, -0.0337,  ...,  0.0098, -0.0132,  0.0051]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.26.mlp.up_proj.weight',
#               tensor([[ 0.0187,  0.0061,  0.0138,  ..., -0.0161, -0.0170, -0.0090],
#                       [-0.0295, -0.0121,  0.0278,  ...,  0.0197,  0.0021,  0.0190],
#                       [ 0.0005,  0.0128, -0.0304,  ..., -0.0127, -0.0040,  0.0175],
#                       ...,
#                       [-0.0006, -0.0111, -0.0164,  ..., -0.0073, -0.0129, -0.0167],
#                       [-0.0107, -0.0211, -0.0045,  ...,  0.0212, -0.0036, -0.0305],
#                       [-0.0078,  0.0273,  0.0203,  ...,  0.0398,  0.0132,  0.0184]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.26.mlp.down_proj.weight',
#               tensor([[-0.0259,  0.0129, -0.0116,  ..., -0.0143,  0.0063,  0.0058],
#                       [-0.0075, -0.0025, -0.0041,  ..., -0.0220,  0.0178,  0.0063],
#                       [-0.0094,  0.0016,  0.0099,  ..., -0.0120, -0.0175, -0.0070],
#                       ...,
#                       [ 0.0378,  0.0159, -0.0065,  ..., -0.0342, -0.0109,  0.0193],
#                       [ 0.0004, -0.0037,  0.0042,  ..., -0.0052,  0.0195,  0.0076],
#                       [ 0.0312, -0.0054, -0.0019,  ..., -0.0170, -0.0130, -0.0136]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.26.input_layernorm.weight',
#               tensor([0.4512, 0.4414, 0.7539,  ..., 0.4609, 0.3984, 0.4160],
#                      dtype=torch.bfloat16)),
#              ('model.layers.26.post_attention_layernorm.weight',
#               tensor([0.4785, 0.4746, 0.4141,  ..., 0.4688, 0.4668, 0.4707],
#                      dtype=torch.bfloat16)),
#              ('model.layers.27.self_attn.q_proj.weight',
#               tensor([[-0.0082,  0.0047,  0.0177,  ...,  0.0065, -0.0138, -0.0025],
#                       [-0.0016,  0.0164, -0.0002,  ..., -0.0315,  0.0012,  0.0024],
#                       [ 0.0139,  0.0171,  0.0117,  ..., -0.0062, -0.0100,  0.0115],
#                       ...,
#                       [ 0.0251,  0.0054,  0.0447,  ..., -0.0179,  0.0008,  0.0205],
#                       [-0.0349, -0.0439, -0.0513,  ...,  0.0229, -0.0072, -0.0114],
#                       [ 0.0317, -0.0176,  0.0011,  ...,  0.0195, -0.0291,  0.0103]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.27.self_attn.k_proj.weight',
#               tensor([[-0.0155,  0.0029, -0.0181,  ...,  0.0063,  0.0364,  0.0166],
#                       [-0.0036, -0.0045, -0.0203,  ..., -0.0058, -0.0034,  0.0043],
#                       [ 0.0410, -0.0035,  0.0396,  ...,  0.0234,  0.0126, -0.0054],
#                       ...,
#                       [-0.0234,  0.0266,  0.0254,  ..., -0.0425, -0.0110, -0.0061],
#                       [ 0.0200,  0.0064, -0.0277,  ..., -0.0021, -0.0283, -0.0258],
#                       [-0.0005,  0.0116, -0.0157,  ..., -0.0046, -0.0253, -0.0334]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.27.self_attn.v_proj.weight',
#               tensor([[ 0.0251, -0.0029,  0.0029,  ..., -0.0165, -0.0155,  0.0077],
#                       [-0.0251,  0.0176, -0.0004,  ...,  0.0033,  0.0366, -0.0334],
#                       [-0.0309, -0.0283,  0.0087,  ..., -0.0137,  0.0002, -0.0012],
#                       ...,
#                       [-0.0029,  0.0126, -0.0121,  ...,  0.0024, -0.0070,  0.0183],
#                       [ 0.0076,  0.0260, -0.0481,  ..., -0.0164, -0.0085, -0.0405],
#                       [-0.0179,  0.0130,  0.0344,  ...,  0.0051, -0.0156,  0.0035]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.27.self_attn.o_proj.weight',
#               tensor([[ 0.0410,  0.0023, -0.0144,  ..., -0.0146,  0.0068,  0.0254],
#                       [-0.0197, -0.0057, -0.0220,  ...,  0.0042, -0.0309, -0.0130],
#                       [ 0.0012,  0.0242,  0.0003,  ...,  0.0361,  0.0125,  0.0254],
#                       ...,
#                       [ 0.0209,  0.0176,  0.0045,  ..., -0.0078, -0.0106, -0.0540],
#                       [-0.0162,  0.0190,  0.0178,  ..., -0.0291,  0.0074,  0.0254],
#                       [ 0.0173, -0.0081,  0.0033,  ..., -0.0117, -0.0025,  0.0118]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.27.mlp.gate_proj.weight',
#               tensor([[-0.0162,  0.0366, -0.0215,  ...,  0.0330,  0.0170, -0.0109],
#                       [ 0.0430, -0.0001,  0.0107,  ...,  0.0320, -0.0085,  0.0132],
#                       [-0.0376,  0.0216,  0.0171,  ..., -0.0064, -0.0019, -0.0200],
#                       ...,
#                       [-0.0020, -0.0114, -0.0264,  ..., -0.0110,  0.0122,  0.0165],
#                       [ 0.0164,  0.0251,  0.0002,  ...,  0.0139,  0.0366, -0.0278],
#                       [ 0.0052, -0.0215,  0.0425,  ...,  0.0063,  0.0047, -0.0023]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.27.mlp.up_proj.weight',
#               tensor([[-0.0136, -0.0400,  0.0198,  ...,  0.0220, -0.0019,  0.0178],
#                       [-0.0223, -0.0093, -0.0101,  ..., -0.0011,  0.0239, -0.0315],
#                       [ 0.0118,  0.0195, -0.0114,  ...,  0.0083,  0.0112,  0.0222],
#                       ...,
#                       [ 0.0405,  0.0276, -0.0071,  ...,  0.0221,  0.0005, -0.0212],
#                       [ 0.0026, -0.0110, -0.0317,  ...,  0.0068, -0.0095,  0.0019],
#                       [-0.0083,  0.0272,  0.0023,  ..., -0.0245,  0.0046, -0.0449]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.27.mlp.down_proj.weight',
#               tensor([[-0.0254,  0.0147,  0.0199,  ..., -0.0095,  0.0148,  0.0023],
#                       [-0.0173,  0.0087, -0.0012,  ..., -0.0281,  0.0254,  0.0037],
#                       [ 0.0007, -0.0381,  0.0039,  ..., -0.0332, -0.0041,  0.0010],
#                       ...,
#                       [ 0.0019,  0.0154,  0.0126,  ...,  0.0146, -0.0325,  0.0197],
#                       [ 0.0088, -0.0283,  0.0311,  ..., -0.0103,  0.0167, -0.0135],
#                       [-0.0060,  0.0079, -0.0002,  ..., -0.0149, -0.0188,  0.0271]],
#                      dtype=torch.bfloat16)),
#              ('model.layers.27.input_layernorm.weight',
#               tensor([0.4199, 0.4316, 0.7734,  ..., 0.4590, 0.4082, 0.3828],
#                      dtype=torch.bfloat16)),
#              ('model.layers.27.post_attention_layernorm.weight',
#               tensor([0.4688, 0.4746, 0.4258,  ..., 0.4473, 0.4355, 0.4492],
#                      dtype=torch.bfloat16)),
#              ('model.norm.weight',
#               tensor([1.7656, 1.7500, 1.5625,  ..., 1.7656, 1.6953, 1.6719],
#                      dtype=torch.bfloat16)),
#              ('lm_head.weight',
#               tensor([[ 1.1292e-02,  9.9487e-03,  1.4160e-02,  ..., -3.5706e-03,
#                        -1.9775e-02,  5.3711e-03],
#                       [ 1.3245e-02, -3.8385e-05,  2.2461e-02,  ..., -2.6550e-03,
#                         3.1738e-02, -1.0681e-03],
#                       [ 1.9775e-02,  2.0020e-02,  2.8687e-02,  ..., -3.5248e-03,
#                         3.1433e-03, -7.6294e-03],
#                       ...,
#                       [-3.0975e-03,  2.1057e-03,  4.8828e-03,  ..., -2.0905e-03,
#                        -1.2207e-03, -2.8992e-03],
#                       [-3.0975e-03,  2.1057e-03,  4.8828e-03,  ..., -2.0905e-03,
#                        -1.2207e-03, -2.8992e-03],
#                       [-3.0975e-03,  2.1057e-03,  4.8828e-03,  ..., -2.0905e-03,
#                        -1.2207e-03, -2.8992e-03]], dtype=torch.bfloat16))])

# %%
weight = model.state_dict()["model.layers.27.mlp.up_proj.weight"].float().numpy()

#上面這段程式碼可以分成三個步驟來看：1. state_dict() 2. ["參數名稱"] 3. .numpy()
# model.state_dict() 方法會回傳一個字典（dict），其鍵（key）為參數名稱，值（value）為張量（Tensor）。
# 可以使用 [] 根據 key 取得對應的 value。
# 這裡的 value 是一個 PyTorch Tensor，.numpy() 會把 Tensor 轉成 NumPy 格式的陣列

print(weight)

#把 weight 中前100×100區塊畫出來
import matplotlib.pyplot as plt
plt.imshow(weight[:100, :100], cmap="RdBu")
plt.colorbar()
plt.show()

#其實看不出甚麼名堂，對吧 ....
# Out:
# [[-0.01361084 -0.04003906  0.01977539 ...  0.02197266 -0.00186157
#    0.01782227]
#  [-0.02233887 -0.00927734 -0.0100708  ... -0.00112152  0.02392578
#   -0.03149414]
#  [ 0.01177979  0.01953125 -0.01135254 ...  0.00830078  0.01123047
#    0.0222168 ]
#  ...
#  [ 0.04052734  0.02758789 -0.00708008 ...  0.02209473  0.00053024
#   -0.02124023]
#  [ 0.00256348 -0.01104736 -0.03173828 ...  0.00680542 -0.00952148
#    0.00187683]
#  [-0.00830078  0.02722168  0.00230408 ... -0.02453613  0.00457764
#   -0.04492188]]

# %% [markdown]
# ## 觀察語言模型中的 Embedding Table

# %%
#先取出model中的 embedding table

input_embedding = model.state_dict()["model.embed_tokens.weight"].float().numpy()

# %% [markdown]
# 查看 input_embedding 的形狀（shape）。

# %%
'''
把 input_embedding 的 shape 輸出出來觀察看看

你會看到 `(128256, 3072)`，表示 `input_embedding` 是一個具有 128,256 列（row）和 3,072 行（column）的矩陣。

- **128256** → 詞彙表（vocabulary）的大小，共有 128,256 個不同的 token。
- **3072** → 每個 token 以一個 3,072 維度的向量表示。

換句話說，每一列（row）對應到一個 token。
'''

print(input_embedding.shape)
# Out:
# (128256, 3072)

# %%
#把 input_embedding 輸出出來觀察看看
print(input_embedding)

#嗯 ... 其實還是看不出甚麼名堂
# Out:
# [[ 1.1291504e-02  9.9487305e-03  1.4160156e-02 ... -3.5705566e-03
#   -1.9775391e-02  5.3710938e-03]
#  [ 1.3244629e-02 -3.8385391e-05  2.2460938e-02 ... -2.6550293e-03
#    3.1738281e-02 -1.0681152e-03]
#  [ 1.9775391e-02  2.0019531e-02  2.8686523e-02 ... -3.5247803e-03
#    3.1433105e-03 -7.6293945e-03]
#  ...
#  [-3.0975342e-03  2.1057129e-03  4.8828125e-03 ... -2.0904541e-03
#   -1.2207031e-03 -2.8991699e-03]
#  [-3.0975342e-03  2.1057129e-03  4.8828125e-03 ... -2.0904541e-03
#   -1.2207031e-03 -2.8991699e-03]
#  [-3.0975342e-03  2.1057129e-03  4.8828125e-03 ... -2.0904541e-03
#   -1.2207031e-03 -2.8991699e-03]]

# %%
#編號為 `token_id` 的 token，其對應的 embedding 就是 `input_embedding` 的第 `token_id` 個列（row）（從 0 開始計數）。
#以下輸出編號為 `token_id` 的 token 以及其對應的 embedding。

token_id = 2

# 從 tokenizer 取得對應 token_id 的 token（文字）
token = tokenizer.decode(token_id)

# 取得該 token 的向量
embedding_vector = input_embedding[token_id]

print(f"Token ID: {token_id}")
print(f"對應的 Token: {token}")
print(f"Token Embedding: {embedding_vector}")
# Out:
# Token ID: 2
# 對應的 Token: #
# Token Embedding: [ 0.01977539  0.02001953  0.02868652 ... -0.00352478  0.00314331
#  -0.00762939]

# %% [markdown]
# ### Token Embedding 相似度分析
#
# 透過分析 Token Embedding，觀察大型語言模型如何在向量空間中表示不同詞彙的語意關係。
#
# 實作過程中，首先將輸入文字轉換為對應的 Token ID，再從模型的 Embedding Layer 擷取該 Token 的向量表示，並使用 **Cosine Similarity（餘弦相似度）** 計算其與詞彙表中其他 Token 的相似程度，最後列出相似度最高的 Top-K Token 進行比較。
#
# 透過此分析，理解 Embedding 並非直接儲存文字意義，而是以高維向量表示語意特徵；語意相近的 Token 在向量空間中的距離通常較近，因此可利用餘弦相似度衡量不同 Token 之間的語意關聯性。此實作也加深了我對 Embedding、Tokenizer 及語意表示（Semantic Representation）等核心概念的理解。

# %%
top_k = 20 #自己設定一個數值

# 1️⃣ 讓使用者輸入一個 token
token = input('請輸入一個 token：') #輸入: apple, Apple, 李, 王 等等

# 2️⃣ 轉換成 token ID
token_id = tokenizer.encode(token)[1]
# 為什麼是 [1]？
# tokenizer.encode() 回傳的是: [BOS_token_id, token_id ...]
# print (tokenizer.encode(token)) <- 跑這一行試試看
# 第一個元素 [0] 是特殊起始符號 (BOS)，
# 我們真正想要的是輸入的那個 token 本身 → 所以取 index 1
print("token id 是 ",token_id)

# 3️⃣ 取得 token 的 embedding
embbeding = [input_embedding[token_id]]

# 4️⃣ 計算餘弦相似度
from sklearn.metrics.pairwise import cosine_similarity
sims = cosine_similarity(embbeding, input_embedding)[0]

# 5️⃣ 排序並取最相近 top_k,並輸出結果
nearest = sims.argsort()[::-1][1: top_k+1] #排除自己本身
print(f'和 {token} 最相近的 {top_k} 個 token：')
for idx in nearest:
  print(f'{tokenizer.decode(idx)} (score: {sims[idx]:.4f})')
# Out:
# 請輸入一個 token：123
# token id 是  4513
# 和 123 最相近的 20 個 token：
# 124 (score: 0.4042)
# 122 (score: 0.3736)
# 121 (score: 0.3049)
# 125 (score: 0.2971)
# 111 (score: 0.2933)
# 120 (score: 0.2783)
# 128 (score: 0.2714)
# 127 (score: 0.2550)
# 23 (score: 0.2528)
# 126 (score: 0.2508)
# 133 (score: 0.2505)
# 234 (score: 0.2433)
# abc (score: 0.2400)
# 113 (score: 0.2364)
# 101 (score: 0.2352)
# 119 (score: 0.2323)
# 456 (score: 0.2301)
# 131 (score: 0.2259)
# 12 (score: 0.2259)
# 129 (score: 0.2250)

# %% [markdown]
# ## 輸出每一層的 representation
#
# 把每一層的 representation 都取出來
#
# ![layer.png](data:image/png;base64,...)

# %%
inputs = tokenizer.encode("大家好", return_tensors="pt")

print("編碼後的 Token IDs：", inputs)

outputs = model(inputs, output_hidden_states=True) # output_hidden_states=True 才會回傳每一層的 representation (hidden states)

hidden_states = outputs.hidden_states
# hidden_states[0] -> embedding （把 token 轉成 token embedding 的結果)
# hidden_states[1] ~ hidden_states[N] -> 每一層 Transformer block 的輸出
print(f"一共拿到 {len(hidden_states)} 層 representation（包含 token embedding）。")

# 列出每層輸出的形狀
for idx, h in enumerate(hidden_states):
    print(f"Layer {idx:2d} 輸出形狀: {h.shape}")
    # h.shape = [batch_size, seq_len, hidden_size]
    # batch_size → 一次處理的句子數
    # sequence_length → 句子被切成多少 token
    # hidden_size → 每個 token 的向量長度


print("\n=== Token Embedding 輸出 ===")
print(hidden_states[0])

print("\n=== 第一個 Transformer Layer 的輸出 ===")
print(hidden_states[1])
# Out:
# 編碼後的 Token IDs： tensor([[128000, 109429,  53901]])
# 一共拿到 29 層 representation（包含 token embedding）。
# Layer  0 輸出形狀: torch.Size([1, 3, 3072])
# Layer  1 輸出形狀: torch.Size([1, 3, 3072])
# Layer  2 輸出形狀: torch.Size([1, 3, 3072])
# Layer  3 輸出形狀: torch.Size([1, 3, 3072])
# Layer  4 輸出形狀: torch.Size([1, 3, 3072])
# Layer  5 輸出形狀: torch.Size([1, 3, 3072])
# Layer  6 輸出形狀: torch.Size([1, 3, 3072])
# Layer  7 輸出形狀: torch.Size([1, 3, 3072])
# Layer  8 輸出形狀: torch.Size([1, 3, 3072])
# Layer  9 輸出形狀: torch.Size([1, 3, 3072])
# Layer 10 輸出形狀: torch.Size([1, 3, 3072])
# Layer 11 輸出形狀: torch.Size([1, 3, 3072])
# Layer 12 輸出形狀: torch.Size([1, 3, 3072])
# Layer 13 輸出形狀: torch.Size([1, 3, 3072])
# Layer 14 輸出形狀: torch.Size([1, 3, 3072])
# Layer 15 輸出形狀: torch.Size([1, 3, 3072])
# Layer 16 輸出形狀: torch.Size([1, 3, 3072])
# Layer 17 輸出形狀: torch.Size([1, 3, 3072])
# Layer 18 輸出形狀: torch.Size([1, 3, 3072])
# Layer 19 輸出形狀: torch.Size([1, 3, 3072])
# Layer 20 輸出形狀: torch.Size([1, 3, 3072])
# Layer 21 輸出形狀: torch.Size([1, 3, 3072])
# Layer 22 輸出形狀: torch.Size([1, 3, 3072])
# Layer 23 輸出形狀: torch.Size([1, 3, 3072])
# Layer 24 輸出形狀: torch.Size([1, 3, 3072])
# Layer 25 輸出形狀: torch.Size([1, 3, 3072])
# Layer 26 輸出形狀: torch.Size([1, 3, 3072])
# Layer 27 輸出形狀: torch.Size([1, 3, 3072])
# Layer 28 輸出形狀: torch.Size([1, 3, 3072])
#
# === Token Embedding 輸出 ===
# tensor([[[-1.1587e-04,  3.8528e-04, -1.9379e-03,  ...,  2.3937e-04,
#           -5.4550e-04,  8.8215e-05],
#          [ 5.1880e-03,  4.0894e-03,  7.6294e-03,  ..., -3.2715e-02,
#           -1.1902e-02, -2.4658e-02],
#          [ 7.2021e-03, -2.0264e-02, -2.5269e-02,  ..., -2.6611e-02,
#            8.9111e-03, -1.4526e-02]]], dtype=torch.bfloat16,
#        grad_fn=<EmbeddingBackward0>)
#
# === 第一個 Transformer Layer 的輸出 ===
# tensor([[[-0.0031,  0.0019,  0.0601,  ...,  0.0510,  0.0021, -0.0049],
#          [-0.0057,  0.0009, -0.0417,  ..., -0.1152, -0.0505, -0.0498],
#          [-0.0129, -0.0004, -0.1436,  ..., -0.0840, -0.0413, -0.0156]]],
#        dtype=torch.bfloat16, grad_fn=<AddBackward0>)

# %% [markdown]
# 比較不同輸入的 representation

# %%
def get_embedding(text, layer_num):
    """
    輸入一句文字，印出模型某一個 layer 的每個 token 的 embedding。

    """
    print(f"\n=== {text} ===")

    inputs = tokenizer.encode(text, return_tensors="pt", add_special_tokens=False)
    #print(inputs)

    outputs = model(inputs, output_hidden_states=True)
    hidden_states = outputs.hidden_states
    hidden_states_layer = hidden_states[layer_num]

    tokens = tokenizer.tokenize(text)
    seq_length = len(tokens)
    for t in range(0,seq_length):
      print(tokens[t], ":", hidden_states_layer[0][t])

layer_num = 10 # 0: token embedding, >0: contextualized token embedding
get_embedding("How about you?", layer_num )
get_embedding("How are you?", layer_num )
get_embedding("Nice to meet you.", layer_num )
# Out:
# === How about you? ===
# How : tensor([-0.3281,  0.6680,  1.4219,  ...,  0.9375,  0.1299,  0.1699],
#        dtype=torch.bfloat16, grad_fn=<SelectBackward0>)
# Ġabout : tensor([-0.0063, -0.0300, -0.0035,  ..., -0.1084,  0.0576, -0.1455],
#        dtype=torch.bfloat16, grad_fn=<SelectBackward0>)
# Ġyou : tensor([-0.0405, -0.0197, -0.0052,  ...,  0.2617, -0.1221,  0.1191],
#        dtype=torch.bfloat16, grad_fn=<SelectBackward0>)
# ? : tensor([ 0.0312, -0.0223,  0.1270,  ..., -0.1055, -0.1904,  0.0645],
#        dtype=torch.bfloat16, grad_fn=<SelectBackward0>)
#
# === How are you? ===
# How : tensor([-0.3281,  0.6680,  1.4219,  ...,  0.9375,  0.1299,  0.1699],
#        dtype=torch.bfloat16, grad_fn=<SelectBackward0>)
# Ġare : tensor([ 0.1875, -0.0635, -0.0488,  ..., -0.1543, -0.0112, -0.0488],
#        dtype=torch.bfloat16, grad_fn=<SelectBackward0>)
# Ġyou : tensor([-0.0232,  0.2617, -0.1338,  ..., -0.0366, -0.1016,  0.0005],
#        dtype=torch.bfloat16, grad_fn=<SelectBackward0>)
# ? : tensor([-0.1196, -0.0454,  0.1309,  ..., -0.0635, -0.1260,  0.0222],
#        dtype=torch.bfloat16, grad_fn=<SelectBackward0>)
#
# === Nice to meet you. ===
# Nice : tensor([-0.2656,  0.6055,  1.2500,  ...,  1.0391,  0.2188,  0.1621],
#        dtype=torch.bfloat16, grad_fn=<SelectBackward0>)
# Ġto : tensor([ 0.0056, -0.0518, -0.2812,  ..., -0.1113, -0.0437,  0.0124],
#        dtype=torch.bfloat16, grad_fn=<SelectBackward0>)
# Ġmeet : tensor([-0.1089,  0.0620,  0.0092,  ...,  0.0327, -0.0535,  0.1670],
#        dtype=torch.bfloat16, grad_fn=<SelectBackward0>)
# Ġyou : tensor([-0.0981,  0.1099, -0.0210,  ...,  0.0200, -0.0854,  0.0322],
#        dtype=torch.bfloat16, grad_fn=<SelectBackward0>)
# . : tensor([-0.0129,  0.1016,  0.3535,  ..., -0.0508, -0.0918,  0.0684],
#        dtype=torch.bfloat16, grad_fn=<SelectBackward0>)

# %%
#比較 sentence1 和 sentence2 中的 "apple" ，在不同層的相似程度

sentence1 = "I ate an apple for breakfast."
idx1 = 4 # apple 在 "I ate an apple for breakfast." 的位置
#[128000, 40, 30912, 459, 24149, 369, 17954, 13]
sentence2 = "The company that brought us the iPad and AirPods is apple."
idx2 = 13 # apple 在 "The tech company apple announced its earnings yesterday." 的位置
#[128000, 791, 2883, 430, 7263, 603,  279, 23067, 323, 6690, 24434, 82,374,  24149, 13]

inputs1 = tokenizer.encode(sentence1,return_tensors="pt")
outputs1 = model(inputs1, output_hidden_states=True)
hidden_states1 = outputs1.hidden_states

inputs2 = tokenizer.encode(sentence2,return_tensors="pt")
outputs2 = model(inputs2, output_hidden_states=True)
hidden_states2 = outputs2.hidden_states

# 計算每一層的 cosine_similarity
distances = []
for l in range(len(hidden_states)):
    vec1 = hidden_states1[l][0][idx1].detach().float().numpy()  # 句子1 中 '▁apple' 的向量
    vec2 = hidden_states2[l][0][idx2].detach().float().numpy()  # 句子2 中 '▁apple' 的向量
    cos_sim = cosine_similarity([vec1], [vec2])[0]
    #print(cos_sim)
    distances.append(cos_sim)

# 繪製距離隨層數變化圖
layers = list(range(len(distances)))
plt.figure(figsize=(6, 4))
plt.plot(layers, distances, marker='o')
plt.xticks(layers)
plt.xlabel("no of layer")
plt.ylabel("Cosine sim")
plt.grid(True)
plt.show()

# %%
sentence1 = "I ate an apple for breakfast."
sentence2 = "The company that brought us the iPad and AirPods is apple."

inputs1 = tokenizer.encode(sentence1, return_tensors="pt")
outputs1 = model(inputs1, output_hidden_states=True)
hidden_states1 = outputs1.hidden_states

inputs2 = tokenizer.encode(sentence2, return_tensors="pt")
outputs2 = model(inputs2, output_hidden_states=True)
hidden_states2 = outputs2.hidden_states

distances = []
for l in range(len(hidden_states)):
    layer_hidden_states1 = hidden_states1[l][0].detach().float().numpy() # Shape: [seq_len1, hidden_size]
    layer_hidden_states2 = hidden_states2[l][0].detach().float().numpy() # Shape: [seq_len2, hidden_size]
    # Calculate pairwise cosine similarity between all tokens in sentence1 and sentence2 for this layer
    pairwise_sim = cosine_similarity(layer_hidden_states1, layer_hidden_states2) # Shape: [seq_len1, seq_len2]
    avg_sim_layer = pairwise_sim.mean()

    vec1 = hidden_states1[l][0][idx1].detach().float().numpy()  # 句子1 中 '▁apple' 的向量
    vec2 = hidden_states2[l][0][idx2].detach().float().numpy()  # 句子2 中 '▁apple' 的向量
    cos_sim = cosine_similarity([vec1], [vec2])[0]

    distances.append(cos_sim/avg_sim_layer)

# 繪製距離隨層數變化圖
layers = list(range(len(distances)))
plt.figure(figsize=(6, 4))
plt.plot(layers, distances, marker='o')
plt.xticks(layers)
plt.xlabel("no of layer")
plt.ylabel("Cosine sim / Average")
plt.grid(True)
plt.show()

# %%
# 定義 4 個句子：前兩句是「可食用的 apple」，後兩句是「Apple 公司」
sentences = [
    "I ate an apple for breakfast.",                 # 可食用的 apple 範例 1
    "She baked an apple pie for dessert.",              # 可食用的 apple 範例 2
    "The tech giant apple announced its quarterly earnings.",    # Apple 公司範例 1
    "Last week the tech giant apple revealed its new iPhone."    # Apple 公司範例 2
]
num_sentences = 4

# 編碼並取得所有層的 hidden_states
hidden_states_batch = []
for i in range(num_sentences):
  inputs = tokenizer.encode(sentences[i], return_tensors="pt")
  #print(inputs)
  outputs = model(inputs, output_hidden_states=True)
  hidden_states_batch.append(outputs.hidden_states)

# 每句中 'apple' 的索引位置
idxs = [4,4,4,6]

# 為每一對句子組合準備相似度儲存結構
pairs = [(0,1), (0,2), (0,3), (1,2), (1,3), (2,3)]
sim_dict = {pair: [] for pair in pairs}

# 逐層計算每對組合的 Cosine 相似度
num_layer = 28
for l in range(num_layer+1):
    for (i, j) in pairs:
        vec_i = hidden_states_batch[i][l][0][idxs[i]].detach().float().numpy()
        vec_j = hidden_states_batch[j][l][0][idxs[j]].detach().float().numpy()
        sim = cosine_similarity([vec_i], [vec_j])[0]
        sim_dict[(i, j)].append(sim)

# 繪製每對組合隨層數變化的相似度曲線
layers = list(range(len(hidden_states)))  # 0 = embedding 層
plt.figure(figsize=(8, 6))
for (i, j), sims in sim_dict.items():
    label = f"sentence{i+1} vs sentence{j+1}"
    plt.plot(layers, sims, marker='o', label=label)

plt.xticks(layers)
plt.xlabel("layer")
plt.ylabel("Cosine")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 以 logit lens 解析 representation

# %% [markdown]
# ### Logit Lens：分析 Transformer 隱藏層表示
#
# 進一步分析 Transformer 模型內部各層的 Hidden Representation，透過 **Logit Lens** 方法觀察模型在不同網路深度下的預測傾向。
#
# 在一般大型語言模型推論流程中，輸入 Token 經過多層 Transformer Layer 後，最後一層 Hidden State 會透過 Language Model Head（LM Head）進行投影，轉換至 Vocabulary Space，產生各 Token 對應的 Logit，並經由 Softmax 取得下一個 Token 的機率分布。
#
# 本實作將 Logit Lens 應用於 Transformer 的中間層表示，於每一層 Hidden Representation 上套用相同的 Unembedding 操作，分析模型在不同層級對下一個 Token 的預測結果。透過比較各層輸出的 Top-K Token，可以觀察模型如何隨著 Transformer Layer 深度增加，逐步形成更完整的語意表示並收斂至最終預測結果。
#
# 透過此分析，進一步理解 Transformer 中間層表示（Intermediate Representation）的變化，以及大型語言模型由低階特徵處理逐步累積至高階語意理解的過程。

# %% [markdown]
# ![lens.png](data:image/png;base64,...)

# %%
text = "天氣" #天氣, 今天天氣真 ...

input_ids = tokenizer.encode(text, return_tensors="pt")
outputs = model(input_ids, output_hidden_states=True)
hidden_states = outputs.hidden_states  # 長度 = layer 數 + 1
print(f"一共拿到 {len(hidden_states)} 層 representation （包含 token embedding）。")

for l in range(len(hidden_states)):
    # 用該層 hidden state 經過 lm_head 得到 logits
    logits = model.lm_head(hidden_states[l])   # [batch, seq_len, vocab_size]

    # 取最後一個 token 的 logits
    last_token_logits = logits[0, -1]  # [vocab_size]

    # 選分數最高的 token
    next_token_id = torch.argmax(last_token_logits)

    # 轉成字
    print(f"Layer {l:2d} → {tokenizer.decode(next_token_id)}")
# Out:
# 一共拿到 29 層 representation （包含 token embedding）。
# Layer  0 → 氣
# Layer  1 → 氣
# Layer  2 → 氣
# Layer  3 → 气
# Layer  4 → 气
# Layer  5 →  weather
# Layer  6 →  weather
# Layer  7 →  weather
# Layer  8 →  weather
# Layer  9 → weather
# Layer 10 → weather
# Layer 11 →  weather
# Layer 12 → weather
# Layer 13 →  favour
# Layer 14 → /weather
# Layer 15 → /weather
# Layer 16 → weather
# Layer 17 → weather
# Layer 18 → /weather
# Layer 19 → /weather
# Layer 20 → /weather
# Layer 21 → /weather
# Layer 22 → /weather
# Layer 23 → /weather
# Layer 24 → /weather
# Layer 25 →  forecast
# Layer 26 →  forecast
# Layer 27 → 的
# Layer 28 → 預

# %% [markdown]
# ## 觀察 Attention 在做甚麼

# %%
#text  = "how are you"
text = "The apple is green. What color is the apple?"

tokens = tokenizer.tokenize(text,add_special_tokens=True)
inputs = tokenizer.encode(text, return_tensors="pt")
model.config._attn_implementation = "eager"
#為什麼需要這個? 告訴模型請老老實實用普通 PyTorch 一步步算 attention，不要用快的方法，這樣 attentions 才會有內容。
outputs = model(inputs, output_attentions=True)


'''
# 把上面幾行的 model -> model2, tokenizer ->　tokenizer2 ，就可以把 llama 換成 gemma 了
tokens = tokenizer2.tokenize(text,add_special_tokens=True)
inputs = tokenizer2.encode(text, return_tensors="pt")
model2.config._attn_implementation = "eager"
outputs = model2(inputs, output_attentions=True)
'''

attentions = outputs.attentions
print(f"總共有 {len(attentions)} 層")
for i, layer_attn in enumerate(attentions):
    print(f"Layer {i} attention shape: {layer_attn.shape}")

# 每一層的 attention 權重張量形狀都是 [1, 24, L, L]。
# 1 → batch_size (一次只輸入一段文字，所以 batch_size = 1)
# 24 → num_heads (這個每一層的 attention 有 24 個，每個 head 都有不同的「關注模式」，例如: 有的關注語法、有的關注語意。)
# L → seq_len（你的輸入句子，經過 tokenizer 之後被切成 L 個 token）
# 總之，每一層有 24 個大小為 L×L 的表格，每個格子是注意力權重（通常 0 ~ 1 之間，row方向加總 ≈ 1）
# Out:
# 總共有 28 層
# Layer 0 attention shape: torch.Size([1, 24, 12, 12])
# Layer 1 attention shape: torch.Size([1, 24, 12, 12])
# Layer 2 attention shape: torch.Size([1, 24, 12, 12])
# Layer 3 attention shape: torch.Size([1, 24, 12, 12])
# Layer 4 attention shape: torch.Size([1, 24, 12, 12])
# Layer 5 attention shape: torch.Size([1, 24, 12, 12])
# Layer 6 attention shape: torch.Size([1, 24, 12, 12])
# Layer 7 attention shape: torch.Size([1, 24, 12, 12])
# Layer 8 attention shape: torch.Size([1, 24, 12, 12])
# Layer 9 attention shape: torch.Size([1, 24, 12, 12])
# Layer 10 attention shape: torch.Size([1, 24, 12, 12])
# Layer 11 attention shape: torch.Size([1, 24, 12, 12])
# Layer 12 attention shape: torch.Size([1, 24, 12, 12])
# Layer 13 attention shape: torch.Size([1, 24, 12, 12])
# Layer 14 attention shape: torch.Size([1, 24, 12, 12])
# Layer 15 attention shape: torch.Size([1, 24, 12, 12])
# Layer 16 attention shape: torch.Size([1, 24, 12, 12])
# Layer 17 attention shape: torch.Size([1, 24, 12, 12])
# Layer 18 attention shape: torch.Size([1, 24, 12, 12])
# Layer 19 attention shape: torch.Size([1, 24, 12, 12])
# Layer 20 attention shape: torch.Size([1, 24, 12, 12])
# Layer 21 attention shape: torch.Size([1, 24, 12, 12])
# Layer 22 attention shape: torch.Size([1, 24, 12, 12])
# Layer 23 attention shape: torch.Size([1, 24, 12, 12])
# Layer 24 attention shape: torch.Size([1, 24, 12, 12])
# Layer 25 attention shape: torch.Size([1, 24, 12, 12])
# Layer 26 attention shape: torch.Size([1, 24, 12, 12])
# Layer 27 attention shape: torch.Size([1, 24, 12, 12])

# %%
layer_idx = 5  #假設我們想觀察第 6 層 (layer_idx=5)
head_idx = 3  #假設我們想觀察第 7 個 Head (head_idx=6) 的注意力分佈 #可以把 6 改成其他數字，例如: 5,4,3

attn_matrix = attentions[layer_idx][0][head_idx].detach().float().numpy()
print(attn_matrix)

import matplotlib.pyplot as plt # Import matplotlib here
plt.imshow(attn_matrix, cmap="viridis")
plt.xticks(range(len(tokens)), tokens, rotation=90)
plt.yticks(range(len(tokens)), tokens)
plt.title(f"Layer {layer_idx+1}, Head {head_idx+1} Attention")
plt.colorbar()
plt.tight_layout()
plt.show()

#你會看到一個 L X L 的矩陣，嘗試解讀你看到了什麼? 為什麼右上角都是0
# Out:
# [[1.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [9.21875000e-01 7.61718750e-02 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [9.33593750e-01 2.36816406e-02 4.22363281e-02 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [9.02343750e-01 4.34570312e-02 3.34472656e-02 2.01416016e-02
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [9.37500000e-01 1.39770508e-02 1.12304688e-02 1.12915039e-03
#   3.71093750e-02 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [8.78906250e-01 2.60009766e-02 1.11694336e-02 1.72424316e-03
#   9.03320312e-03 7.42187500e-02 0.00000000e+00 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [9.17968750e-01 3.19824219e-02 8.85009766e-03 2.34985352e-03
#   4.60815430e-03 1.15356445e-02 2.28271484e-02 0.00000000e+00
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [2.89062500e-01 8.60595703e-03 3.61328125e-02 1.96838379e-03
#   5.46875000e-01 8.78906250e-02 4.13894653e-04 2.85644531e-02
#   0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [5.35156250e-01 1.39160156e-02 2.74658203e-02 5.15747070e-03
#   1.99218750e-01 1.81640625e-01 4.39453125e-03 2.16064453e-02
#   1.25732422e-02 0.00000000e+00 0.00000000e+00 0.00000000e+00]
#  [4.04296875e-01 2.01416016e-02 4.54101562e-02 3.56445312e-02
#   2.03125000e-01 2.53906250e-01 6.74438477e-03 1.85546875e-02
#   1.89971924e-03 1.05590820e-02 0.00000000e+00 0.00000000e+00]
#  [2.23632812e-01 7.01904297e-03 5.54687500e-01 1.26953125e-01
#   1.42822266e-02 2.88085938e-02 1.54113770e-03 2.04086304e-04
#   9.23871994e-06 9.05990601e-05 4.39453125e-02 0.00000000e+00]
#  [5.07812500e-01 1.92871094e-02 7.71484375e-02 1.24511719e-02
#   1.43554688e-01 2.05078125e-01 7.93457031e-03 5.73730469e-03
#   8.01086426e-04 1.29699707e-03 7.28607178e-04 1.86767578e-02]]

# %%
num_layers = len(attentions)
num_heads = attentions[0].shape[1]  # 每層 head 數

# 建立總圖
fig, axes = plt.subplots(num_layers, num_heads, figsize=(num_heads*1.5, num_layers*1.5))
if num_layers == 1 and num_heads == 1:
    axes = [[axes]]
elif num_layers == 1:
    axes = [axes]
elif num_heads == 1:
    axes = [[ax] for ax in axes]

# 畫每個子圖
for layer_idx in range(num_layers):
    for head_idx in range(num_heads):
        ax = axes[layer_idx][head_idx]
        attn_matrix = attentions[layer_idx][0, head_idx].detach().cpu().float().numpy()
        ax.imshow(attn_matrix, cmap="viridis")
        ax.set_xticks([])
        ax.set_yticks([])
        ax.set_title(f"L{layer_idx+1}\nH{head_idx+1}", fontsize=6)

#plt.suptitle("Attention Maps (Layer × Head)", fontsize=14)
plt.tight_layout()
plt.show()
